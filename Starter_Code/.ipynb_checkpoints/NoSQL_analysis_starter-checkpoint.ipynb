# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
# Display the first document in the results using pprint
first_document = establishments.find_one(query)
pprint(first_document)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('678327394905d7d928297d5b'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame([first_document])
# Display the number of rows in the DataFrame
print("Number of rows:", len(df))
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows: 1
#                         _id  FHRSID  ChangesByServerID  \
# 0  678327394905d7d928297d5b  110681                  0
#
#   LocalAuthorityBusinessID         BusinessName     BusinessType  \
# 0                     4029  The Chase Rest Home  Caring Premises
#
#    BusinessTypeID          AddressLine1 AddressLine2 AddressLine3  ...  \
# 0               5  5-6 Southfields Road   Eastbourne  East Sussex  ...
#
#                       LocalAuthorityWebSite       LocalAuthorityEmailAddress  \
# 0  http://www.eastbourne.gov.uk/foodratings  Customerfirst@eastbourne.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                          geocode RightToReply     Distance  \
# 0  {'longitude': 0.27694, 'latitude': 50.769705}               4613.888288
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [1 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName": {'$regex': "London"}, "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of establishments with RatingValue >= 4 in London: {count}")
# Display the first document in the results using pprint
second_document = establishments.find_one(query)
pprint(second_document)
# Out:
# Number of establishments with RatingValue >= 4 in London: 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d928299779'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
documents = list(establishments.find(query))
df = pd.DataFrame(documents)
# Display the number of rows in the DataFrame
print("Number of rows:", len(df))
# Display the first 10 rows of the DataFrame
df.head(12)
# Out:
# Number of rows: 33
#                          _id   FHRSID  ChangesByServerID  \
# 0   6783273a4905d7d928299779   621707                  0
# 1   6783273a4905d7d928299a9c  1130836                  0
# 2   6783273a4905d7d92829a5e7   293783                  0
# 3   6783273a4905d7d92829b3e8  1315095                  0
# 4   6783273a4905d7d92829b3e9   294474                  0
# 5   6783273a4905d7d92829baf5   294900                  0
# 6   6783273b4905d7d92829dc00   293756                  0
# 7   6783273b4905d7d92829dfc8   878523                  0
# 8   6783273b4905d7d92829dfe0   293772                  0
# 9   6783273b4905d7d92829dfe1   295107                  0
# 10  6783273b4905d7d92829dff7   294606                  0
# 11  6783273b4905d7d92829e1c3   294523                  0
#
#    LocalAuthorityBusinessID                          BusinessName  \
# 0              PI/000025307                             Charlie's
# 1              PI/000034075               Mv City Cruises Erasmus
# 2              PI/000002614             Benfleet Motor Yacht Club
# 3              PI/000036464  Coombs Catering t/a The Lock and Key
# 4              PI/000014647              Tilbury Seafarers Centre
# 5              PI/000019066                            Mv Valulla
# 6              PI/000002538                         Tereza Joanne
# 7              PI/000029844                      Brick Lane Brews
# 8              PI/000002585         The Nuance Group (UK) Limited
# 9              PI/000020749                      City Bar & Grill
# 10             PI/000016185                              WH Smith
# 11             PI/000015222                            Jet Centre
#
#                BusinessType  BusinessTypeID  \
# 0   Other catering premises            7841
# 1   Other catering premises            7841
# 2   Other catering premises            7841
# 3   Restaurant/Cafe/Canteen               1
# 4   Restaurant/Cafe/Canteen               1
# 5   Other catering premises            7841
# 6   Other catering premises            7841
# 7   Restaurant/Cafe/Canteen               1
# 8         Retailers - other            4613
# 9   Restaurant/Cafe/Canteen               1
# 10        Retailers - other            4613
# 11  Restaurant/Cafe/Canteen               1
#
#                                          AddressLine1  \
# 0          Oak Apple Farm Building 103 Sheernes Docks
# 1                                  Cherry Garden Pier
# 2                                          Ferry Road
# 3                                   Leslie Ford House
# 4                           Tenants Row Tilbury Docks
# 5   Reeds River Cruises LtdKings ReachRiver Thames...
# 6   Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                        Air side London City Airport
# 8                   Duty Free Shop Passenger Terminal
# 9                       London City Airport (Airside)
# 10                                London City Airport
# 11                                London City Airport
#
#                             AddressLine2 AddressLine3  ...  \
# 0                            Sheppy Kent               ...
# 1       Cherry Garden Street Rotherhithe     Charlton  ...
# 2                   South Benfleet Essex               ...
# 3                                Tilbury     Charlton  ...
# 4                          Tilbury Essex               ...
# 5                                 London               ...
# 6                                 London               ...
# 7                                 London               ...
# 8   London City AirportRoyal DocksLondon               ...
# 9                                 London               ...
# 10                     Silvertown London               ...
# 11                    Royal Docks London               ...
#
#                                 LocalAuthorityWebSite  \
# 0   http://www.cityoflondon.gov.uk/Corporation/hom...
# 1   http://www.cityoflondon.gov.uk/Corporation/hom...
# 2   http://www.cityoflondon.gov.uk/Corporation/hom...
# 3   http://www.cityoflondon.gov.uk/Corporation/hom...
# 4   http://www.cityoflondon.gov.uk/Corporation/hom...
# 5   http://www.cityoflondon.gov.uk/Corporation/hom...
# 6   http://www.cityoflondon.gov.uk/Corporation/hom...
# 7   http://www.cityoflondon.gov.uk/Corporation/hom...
# 8   http://www.cityoflondon.gov.uk/Corporation/hom...
# 9   http://www.cityoflondon.gov.uk/Corporation/hom...
# 10  http://www.cityoflondon.gov.uk/Corporation/hom...
# 11  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#               LocalAuthorityEmailAddress  \
# 0   publicprotection@cityoflondon.gov.uk
# 1   publicprotection@cityoflondon.gov.uk
# 2   publicprotection@cityoflondon.gov.uk
# 3   publicprotection@cityoflondon.gov.uk
# 4   publicprotection@cityoflondon.gov.uk
# 5   publicprotection@cityoflondon.gov.uk
# 6   publicprotection@cityoflondon.gov.uk
# 7   publicprotection@cityoflondon.gov.uk
# 8   publicprotection@cityoflondon.gov.uk
# 9   publicprotection@cityoflondon.gov.uk
# 10  publicprotection@cityoflondon.gov.uk
# 11  publicprotection@cityoflondon.gov.uk
#
#                                                scores  SchemeType  \
# 0   {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7   {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 10  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 11  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                               geocode RightToReply  \
# 0      {'longitude': 0.508551, 'latitude': 51.369321}
# 1   {'longitude': 0.249255999922752, 'latitude': 5...
# 2      {'longitude': 0.561954, 'latitude': 51.543831}
# 3   {'longitude': 0.346336990594864, 'latitude': 5...
# 4      {'longitude': 0.346325, 'latitude': 51.464078}
# 5      {'longitude': 0.287555, 'latitude': 51.504071}
# 6      {'longitude': 0.069286, 'latitude': 51.501121}
# 7      {'longitude': 0.048006, 'latitude': 51.503733}
# 8      {'longitude': 0.047966, 'latitude': 51.504112}
# 9   {'longitude': 0.0479655750095844, 'latitude': ...
# 10  {'longitude': 0.0479655750095844, 'latitude': ...
# 11  {'longitude': 0.0405181497335434, 'latitude': ...
#
#        Distance NewRatingPending  \
# 0   4627.439468            False
# 1   4627.873179            False
# 2   4631.968418            False
# 3   4636.846754            False
# 4   4636.847650            False
# 5   4640.460834            False
# 6   4648.301822            False
# 7   4649.173485            False
# 8   4649.188826            False
# 9   4649.188850            False
# 10  4649.188850            False
# 11  4649.485870            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'https://api.ratings....
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [12 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Coordinates of "Penang Flavours"
latitude = 51.49014200
longitude = 0.08384000

# Define the search range (0.01 degrees for a small area)
degree_search = 0.05  # Adjust if needed

# Query to find establishments near Penang Flavours (within 0.05 degrees)
query = {
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
}

# Search for nearby establishments
results = establishments.find(query)

# Print the results to see the nearby establishments
for result in results:
    pprint(result)

# Convert the results to a Pandas DataFrame to view more clearly
#documents = list(establishments.find(query))
#df = pd.DataFrame(documents)

# Display the number of rows in the DataFrame
#print("Number of nearby establishments:", len(df))

# Display the first 10 rows of the DataFrame
#df.head(11)
# Out:
# {'AddressLine1': '6 Dorchester Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Forster Botanical',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.027786900985,
#  'FHRSID': 996687,
#  'LocalAuthorityBusinessID': '17/00259/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AJ',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_exempt_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c797'),
#  'geocode': {'latitude': 51.4409866333008, 'longitude': 0.126010000705719},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/996687',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'Dorchester Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Nourish Contract Catering At Hurst Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4644.027763697427,
#  'FHRSID': 990548,
#  'LocalAuthorityBusinessID': '17/00225/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AJ',
#  'RatingDate': '2022-02-25T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c798'),
#  'geocode': {'latitude': 51.440986, 'longitude': 0.12601},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/990548',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '113 Bladindon Drive',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Debz Cooper Independent Cambridge Weight Plan Consultant',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.079763888749,
#  'FHRSID': 1246900,
#  'LocalAuthorityBusinessID': '20/00107/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3BT',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_exempt_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c7ed'),
#  'geocode': {'latitude': 51.4443147, 'longitude': 0.1279308},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1246900',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '9 Montpelier Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Silver Fox Micro Pub',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4644.084590792842,
#  'FHRSID': 1229242,
#  'LocalAuthorityBusinessID': '20/00030/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AP',
#  'RatingDate': '2020-08-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c7ef'),
#  'geocode': {'latitude': 51.4421709, 'longitude': 0.1256438},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1229242',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '17 Montpelier Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Hideout',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.104195712933,
#  'FHRSID': 1286024,
#  'LocalAuthorityBusinessID': '20/00343/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AP',
#  'RatingDate': '2021-01-14T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c809'),
#  'geocode': {'latitude': 51.442225, 'longitude': 0.125161},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1286024',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '7 Montpelier Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Craft T Cake',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.104195712933,
#  'FHRSID': 984338,
#  'LocalAuthorityBusinessID': '17/00206/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AP',
#  'RatingDate': '2017-10-25T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c80a'),
#  'geocode': {'latitude': 51.442225, 'longitude': 0.125161},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/984338',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '5 Montpelier Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Ocean Fresh',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.104195712933,
#  'FHRSID': 1396906,
#  'LocalAuthorityBusinessID': '21/00260/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AP',
#  'RatingDate': '2021-10-06T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': 3,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c80b'),
#  'geocode': {'latitude': 51.442225, 'longitude': 0.125161},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1396906',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': '21 Montpelier Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': "Deo's Local",
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.104195712933,
#  'FHRSID': 945346,
#  'LocalAuthorityBusinessID': '17/00049/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AP',
#  'RatingDate': '2019-12-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c80c'),
#  'geocode': {'latitude': 51.442225, 'longitude': 0.125161},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/945346',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '68 Crofton Avenue',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Bubbles Nurseries',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4644.169479961963,
#  'FHRSID': 1004958,
#  'LocalAuthorityBusinessID': '17/00295/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3AT',
#  'RatingDate': '2021-10-28T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d92829c87e'),
#  'geocode': {'latitude': 51.442981, 'longitude': 0.124132},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1004958',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Bexleyheath Golf Club',
#  'AddressLine2': 'Mount Drive',
#  'AddressLine3': 'Bexleyheath',
#  'AddressLine4': 'Bexley',
#  'BusinessName': 'ABCatering',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.220972719068,
#  'FHRSID': 1383551,
#  'LocalAuthorityBusinessID': '21/00184/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8JS',
#  'RatingDate': '2021-09-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c8c7'),
#  'geocode': {'latitude': 51.4517582, 'longitude': 0.1315445},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1383551',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Bexleyheath Club For Disabled',
#  'AddressLine2': 'Barton Close',
#  'AddressLine3': 'Bexleyheath',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Bexleyheath & District Club For Disabled',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.2424149781655,
#  'FHRSID': 1136993,
#  'LocalAuthorityBusinessID': '19/00098/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8JP',
#  'RatingDate': '2019-06-26T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c8ee'),
#  'geocode': {'latitude': 51.4534111022949, 'longitude': 0.132618993520737},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1136993',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Bladindon Drive',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Blendon Pre-school At St. James Church Hall',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4644.29202206107,
#  'FHRSID': 687072,
#  'LocalAuthorityBusinessID': '05150/2002/2/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 3BS',
#  'RatingDate': '2018-11-15T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c937'),
#  'geocode': {'latitude': 51.444321, 'longitude': 0.122121},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/687072',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Mount Road',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Bexleyheath Golf Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4644.3153779006125,
#  'FHRSID': 768540,
#  'LocalAuthorityBusinessID': '10/00146/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8JS',
#  'RatingDate': '2017-12-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c96d'),
#  'geocode': {'latitude': 51.452149, 'longitude': 0.12935},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/768540',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '68 Mount Road',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Royal Oak',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4644.3153779006125,
#  'FHRSID': 738298,
#  'LocalAuthorityBusinessID': '08850/0068/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8JS',
#  'RatingDate': '2018-01-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c96f'),
#  'geocode': {'latitude': 51.452149, 'longitude': 0.12935},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/738298',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '309A Broadway',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': "Domino's Pizza",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.389552835672,
#  'FHRSID': 954337,
#  'LocalAuthorityBusinessID': '17/00088/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8DT',
#  'RatingDate': '2019-03-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9b1'),
#  'geocode': {'latitude': 51.457811, 'longitude': 0.133011},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/954337',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '331 Broadway',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Jasmine By Spice Nouv-Oh!',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.389552835672,
#  'FHRSID': 990539,
#  'LocalAuthorityBusinessID': '17/00215/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8DT',
#  'RatingDate': '2022-01-28T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9b2'),
#  'geocode': {'latitude': 51.457811, 'longitude': 0.133011},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/990539',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}}
# {'AddressLine1': '307A Broadway',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Broadway Traditional Fish & Chips',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.389552835672,
#  'FHRSID': 329312,
#  'LocalAuthorityBusinessID': '07080/0307/A/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8DT',
#  'RatingDate': '2020-11-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9b3'),
#  'geocode': {'latitude': 51.457811, 'longitude': 0.133011},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329312',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '309 Broadway',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'India Gate',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.389552835672,
#  'FHRSID': 1494703,
#  'LocalAuthorityBusinessID': '22/00099/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8DT',
#  'RatingDate': '2022-08-16T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': 3,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9b4'),
#  'geocode': {'latitude': 51.457811, 'longitude': 0.133011},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1494703',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 5}}
# {'AddressLine1': '71 Alers Road',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Alers Stores (Londis)',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.398186587946,
#  'FHRSID': 580845,
#  'LocalAuthorityBusinessID': '06690/0071/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8HT',
#  'RatingDate': '2020-11-02T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9b7'),
#  'geocode': {'latitude': 51.451889, 'longitude': 0.126819},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/580845',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 10}}
# {'AddressLine1': '118 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Three Blackbirds Public House',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4644.4264208685,
#  'FHRSID': 329219,
#  'LocalAuthorityBusinessID': '05170/0118/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BX',
#  'RatingDate': '2019-02-26T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9d2'),
#  'geocode': {'latitude': 51.448238, 'longitude': 0.122375},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329219',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '14 Upton Road',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Croft Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4644.432924435033,
#  'FHRSID': 1387945,
#  'LocalAuthorityBusinessID': '21/00219/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8LQ',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9d3'),
#  'geocode': {'latitude': 51.4571255, 'longitude': 0.1311326},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1387945',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '310A Broadway',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Best Kebab',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.434901927625,
#  'FHRSID': 1138635,
#  'LocalAuthorityBusinessID': '18/00324/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8AA',
#  'RatingDate': '2018-12-20T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9dd'),
#  'geocode': {'latitude': 51.458522, 'longitude': 0.132483},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1138635',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Red House Lane',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Red House Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.4346480039485,
#  'FHRSID': 580844,
#  'LocalAuthorityBusinessID': '04/00121/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8JF',
#  'RatingDate': '2018-03-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9df'),
#  'geocode': {'latitude': 51.455572, 'longitude': 0.129523},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/580844',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '323 - 325 Broadway',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Nisa Local',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.442806037754,
#  'FHRSID': 1064850,
#  'LocalAuthorityBusinessID': '18/00165/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8DT',
#  'RatingDate': '2021-03-15T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': 3,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9e0'),
#  'geocode': {'latitude': 51.4582784, 'longitude': 0.1320213},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1064850',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': '135 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Thai Lounge',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.447646712961,
#  'FHRSID': 1283068,
#  'LocalAuthorityBusinessID': '20/00319/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2021-02-23T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9e9'),
#  'geocode': {'latitude': 51.447974, 'longitude': 0.121528},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1283068',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': '143 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Pizza Place',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.447646712961,
#  'FHRSID': 329222,
#  'LocalAuthorityBusinessID': '05170/0143/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2018-12-04T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': 3,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9ea'),
#  'geocode': {'latitude': 51.447974, 'longitude': 0.121528},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329222',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': '147-149 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Co-Operative',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4644.447646712961,
#  'FHRSID': 587324,
#  'LocalAuthorityBusinessID': '05170/0147/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2019-04-15T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9eb'),
#  'geocode': {'latitude': 51.447974, 'longitude': 0.121528},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/587324',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '133 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Dragon Express',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.447646712961,
#  'FHRSID': 329220,
#  'LocalAuthorityBusinessID': '05170/0133/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2020-02-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9ec'),
#  'geocode': {'latitude': 51.447974, 'longitude': 0.121528},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329220',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '145 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Saggor',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.447646712961,
#  'FHRSID': 1038534,
#  'LocalAuthorityBusinessID': '18/00042/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2020-02-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9ee'),
#  'geocode': {'latitude': 51.447974, 'longitude': 0.121528},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1038534',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '157 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': "Maddison's Bakery",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4644.450894924376,
#  'FHRSID': 904095,
#  'LocalAuthorityBusinessID': '16/00232/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2018-07-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9f6'),
#  'geocode': {'latitude': 51.447976, 'longitude': 0.121441},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/904095',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': '141 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Patfam',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.450894924376,
#  'FHRSID': 329221,
#  'LocalAuthorityBusinessID': '05170/0141/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2021-06-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9f7'),
#  'geocode': {'latitude': 51.447976, 'longitude': 0.121441},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/329221',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '161 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Bexley Food & Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.450894924376,
#  'FHRSID': 894458,
#  'LocalAuthorityBusinessID': '16/00118/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2019-09-03T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829c9f8'),
#  'geocode': {'latitude': 51.447976, 'longitude': 0.121441},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/894458',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 10}}
# {'AddressLine1': '155 Blendon Road',
#  'AddressLine2': 'Bexley',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Blush Parties And Balloons',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4644.4657393998805,
#  'FHRSID': 1384872,
#  'LocalAuthorityBusinessID': '21/00211/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA5 1BT',
#  'RatingDate': '2021-06-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829ca03'),
#  'geocode': {'latitude': 51.4479917, 'longitude': 0.12105},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1384872',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '6 Crook Log',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Crook Log Guest House',
#  'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  'ChangesByServerID': 0,
#  'Distance': 4644.475701893332,
#  'FHRSID': 687099,
#  'LocalAuthorityBusinessID': '07410/0006/0/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8BW',
#  'RatingDate': '2020-02-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829ca0c'),
#  'geocode': {'latitude': 51.458772, 'longitude': 0.131616},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/687099',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '13-15 Crook Log',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Asda',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4644.499092830918,
#  'FHRSID': 580849,
#  'LocalAuthorityBusinessID': '07410/0013/4/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8DZ',
#  'RatingDate': '2020-01-15T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829ca23'),
#  'geocode': {'latitude': 51.458465, 'longitude': 0.130666},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/580849',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '264 Sherwood Park Avenue',
#  'AddressLine2': 'Sidcup',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': "Baba's Kebab",
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4644.556631060331,
#  'FHRSID': 1343374,
#  'LocalAuthorityBusinessID': '21/00075/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA15 9JN',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829ca61'),
#  'geocode': {'latitude': 51.4474971, 'longitude': 0.1180623},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1343374',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '38 - 42 Bean Road',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Enchanted Wood Pre-School At Scout Hut',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4644.560657971487,
#  'FHRSID': 632838,
#  'LocalAuthorityBusinessID': '11/00134/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA6 8HN',
#  'RatingDate': '2017-06-30T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829ca62'),
#  'geocode': {'latitude': 51.455377, 'longitude': 0.125873},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/632838',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '242 Sherwood Park Avenue',
#  'AddressLine2': 'Sidcup',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Newsmarket Store (Premier)',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4644.563353157744,
#  'FHRSID': 1009734,
#  'LocalAuthorityBusinessID': '17/00320/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA15 9JN',
#  'RatingDate': '2017-10-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829ca63'),
#  'geocode': {'latitude': 51.4474830627441, 'longitude': 0.117863997817039},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1009734',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': 'Station Road',
#  'AddressLine2': 'Bexleyheath',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': "Puccino's At Bexleyheath Railway Station",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4644.568715608853,
#  'FHRSID': 740451,
#  'LocalAuthorityBusinessID': '15/00048/CP',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA7 4AA',
# ...
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e5fa'),
#  'geocode': {'latitude': 51.523017, 'longitude': 0.035378},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1030001',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Newham University Hospital',
#  'AddressLine2': 'Glen Road',
#  'AddressLine3': 'Plaistow',
#  'AddressLine4': 'London',
#  'BusinessName': 'Eatwell (Staff Restaurant) - Zone 5 1st Floor',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4650.340214307119,
#  'FHRSID': 1030000,
#  'LocalAuthorityBusinessID': '18/00061/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8SL',
#  'RatingDate': '2020-01-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e5fb'),
#  'geocode': {'latitude': 51.523017, 'longitude': 0.035378},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1030000',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Newham Centre For Mental Health',
#  'AddressLine2': 'Glen Road',
#  'AddressLine3': 'Plaistow',
#  'AddressLine4': 'London',
#  'BusinessName': 'GFM Ltd - Newham Centre Staff & Public Canteen',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.340214477816,
#  'FHRSID': 1024776,
#  'LocalAuthorityBusinessID': '18/00006/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8SP',
#  'RatingDate': '2020-03-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e5fc'),
#  'geocode': {'latitude': 51.523018, 'longitude': 0.035379},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1024776',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Newham Centre For Mental Health',
#  'AddressLine2': 'Glen Road',
#  'AddressLine3': 'Plaistow',
#  'AddressLine4': 'London',
#  'BusinessName': 'GFM Ltd - Newham Centre CAHMS Ward',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.340214477816,
#  'FHRSID': 1024777,
#  'LocalAuthorityBusinessID': '18/00007/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8SP',
#  'RatingDate': '2020-03-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e5fd'),
#  'geocode': {'latitude': 51.523018, 'longitude': 0.035379},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1024777',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Newham Centre For Mental Health',
#  'AddressLine2': 'Glen Road',
#  'AddressLine3': 'Plaistow',
#  'AddressLine4': 'London',
#  'BusinessName': 'GFM Ltd - Newham Centre Central Production Kitchen',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4650.340214477816,
#  'FHRSID': 680572,
#  'LocalAuthorityBusinessID': '14/00519/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8SP',
#  'RatingDate': '2020-03-06T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e5fe'),
#  'geocode': {'latitude': 51.523018, 'longitude': 0.035379},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/680572',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Kiosk Within Station',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4650.340763355638,
#  'FHRSID': 849263,
#  'LocalAuthorityBusinessID': '05/00116/COMM',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 2JA',
#  'RatingDate': '2018-11-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e5ff'),
#  'geocode': {'latitude': 51.539005, 'longitude': 0.051435},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/849263',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '182 - 184 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Lidl UK',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4650.340763355638,
#  'FHRSID': 747715,
#  'LocalAuthorityBusinessID': '69050/0182/0/000',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 2JA',
#  'RatingDate': '2019-01-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e600'),
#  'geocode': {'latitude': 51.539005, 'longitude': 0.051435},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/747715',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'The Cafe Gateway Surgical Centre',
#  'AddressLine2': 'Newham General Hospital',
#  'AddressLine3': 'Glen Road',
#  'AddressLine4': 'Plaistow',
#  'BusinessName': 'Fontanella Coffee House',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.339353660622,
#  'FHRSID': 1030002,
#  'LocalAuthorityBusinessID': '18/00063/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E13 8SL',
#  'RatingDate': '2020-01-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e601'),
#  'geocode': {'latitude': 51.523006439209, 'longitude': 0.0353909991681576},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1030002',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '166 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Carpathia',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4650.340763355638,
#  'FHRSID': 919552,
#  'LocalAuthorityBusinessID': '16/00508/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 2JA',
#  'RatingDate': '2019-07-12T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e602'),
#  'geocode': {'latitude': 51.539005, 'longitude': 0.051435},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/919552',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': '198 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Dixy Chicken',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4650.34080000078,
#  'FHRSID': 640365,
#  'LocalAuthorityBusinessID': '10/00282/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 2JA',
#  'RatingDate': '2020-12-01T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e603'),
#  'geocode': {'latitude': 51.539006, 'longitude': 0.051435},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640365',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}
# {'AddressLine1': '216 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Cakes And Bakes',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4650.34080000078,
#  'FHRSID': 640977,
#  'LocalAuthorityBusinessID': '69050/0216/0/000',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 2JA',
#  'RatingDate': '2020-12-01T00:00:00',
#  'RatingKey': 'fhrs_3_en-gb',
#  'RatingValue': 3,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e604'),
#  'geocode': {'latitude': 51.539006, 'longitude': 0.051435},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/640977',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 10, 'Structural': 10}}
# {'AddressLine1': '206 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Vasantha Vilas',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4650.34080000078,
#  'FHRSID': 1220614,
#  'LocalAuthorityBusinessID': '20/00047/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 2JA',
#  'RatingDate': '2020-12-07T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e605'),
#  'geocode': {'latitude': 51.539006, 'longitude': 0.051435},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1220614',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 10, 'Structural': 5}}
# {'AddressLine1': '226 High Street North',
#  'AddressLine2': 'East Ham',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Sasi Cash And Carry',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4650.34080000078,
#  'FHRSID': 654093,
#  'LocalAuthorityBusinessID': '12/00366/FOOD',
#  'LocalAuthorityCode': '525',
#  'LocalAuthorityEmailAddress': 'food@newham.gov.uk',
#  'LocalAuthorityName': 'Newham',
#  'LocalAuthorityWebSite': 'https://www.newham.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'E6 2JA',
#  'RatingDate': '2017-07-17T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829e606'),
#  'geocode': {'latitude': 51.539006, 'longitude': 0.051435},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/654093',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Convert the results to a Pandas DataFrame to view more clearly
documents = list(establishments.find(query))
df = pd.DataFrame(documents)

# Display the number of rows in the DataFrame
print("Number of nearby establishments:", len(df))

# Display the first 10 rows of the DataFrame
df.head(11)
# Out:
# Number of nearby establishments: 2392
#                          _id     FHRSID  ChangesByServerID  \
# 0   6783273a4905d7d92829c797   996687.0                0.0
# 1   6783273a4905d7d92829c798   990548.0                0.0
# 2   6783273a4905d7d92829c7ed  1246900.0                0.0
# 3   6783273a4905d7d92829c7ef  1229242.0                0.0
# 4   6783273a4905d7d92829c809  1286024.0                0.0
# 5   6783273a4905d7d92829c80a   984338.0                0.0
# 6   6783273a4905d7d92829c80b  1396906.0                0.0
# 7   6783273a4905d7d92829c80c   945346.0                0.0
# 8   6783273a4905d7d92829c87e  1004958.0                0.0
# 9   6783273b4905d7d92829c8c7  1383551.0                0.0
# 10  6783273b4905d7d92829c8ee  1136993.0                0.0
#
#    LocalAuthorityBusinessID  \
# 0               17/00259/CP
# 1               17/00225/CP
# 2               20/00107/CP
# 3               20/00030/CP
# 4               20/00343/CP
# 5               17/00206/CP
# 6               21/00260/CP
# 7               17/00049/CP
# 8               17/00295/CP
# 9               21/00184/CP
# 10              19/00098/CP
#
#                                          BusinessName  \
# 0                                   Forster Botanical
# 1   Nourish Contract Catering At Hurst Primary School
# 2   Debz Cooper Independent Cambridge Weight Plan ...
# 3                                Silver Fox Micro Pub
# 4                                         The Hideout
# 5                                        Craft T Cake
# 6                                         Ocean Fresh
# 7                                         Deo's Local
# 8                                   Bubbles Nurseries
# 9                                          ABCatering
# 10           Bexleyheath & District Club For Disabled
#
#                  BusinessType BusinessTypeID                   AddressLine1  \
# 0           Retailers - other           4613            6 Dorchester Avenue
# 1   School/college/university           7845              Dorchester Avenue
# 2           Retailers - other           4613            113 Bladindon Drive
# 3           Pub/bar/nightclub           7843            9 Montpelier Avenue
# 4     Restaurant/Cafe/Canteen              1           17 Montpelier Avenue
# 5     Restaurant/Cafe/Canteen              1            7 Montpelier Avenue
# 6      Takeaway/sandwich shop           7844            5 Montpelier Avenue
# 7           Retailers - other           4613           21 Montpelier Avenue
# 8             Caring Premises              5              68 Crofton Avenue
# 9     Restaurant/Cafe/Canteen              1          Bexleyheath Golf Club
# 10    Restaurant/Cafe/Canteen              1  Bexleyheath Club For Disabled
#
#     AddressLine2 AddressLine3  ...     LocalAuthorityWebSite  \
# 0         Bexley         Kent  ...  http://www.bexley.gov.uk
# 1         Bexley         Kent  ...  http://www.bexley.gov.uk
# 2         Bexley         Kent  ...  http://www.bexley.gov.uk
# 3         Bexley         Kent  ...  http://www.bexley.gov.uk
# 4         Bexley         Kent  ...  http://www.bexley.gov.uk
# 5         Bexley         Kent  ...  http://www.bexley.gov.uk
# 6         Bexley         Kent  ...  http://www.bexley.gov.uk
# 7         Bexley         Kent  ...  http://www.bexley.gov.uk
# 8         Bexley         Kent  ...  http://www.bexley.gov.uk
# 9    Mount Drive  Bexleyheath  ...  http://www.bexley.gov.uk
# 10  Barton Close  Bexleyheath  ...  http://www.bexley.gov.uk
#
#    LocalAuthorityEmailAddress  \
# 0   food.safety@bexley.gov.uk
# 1   food.safety@bexley.gov.uk
# 2   food.safety@bexley.gov.uk
# 3   food.safety@bexley.gov.uk
# 4   food.safety@bexley.gov.uk
# 5   food.safety@bexley.gov.uk
# 6   food.safety@bexley.gov.uk
# 7   food.safety@bexley.gov.uk
# 8   food.safety@bexley.gov.uk
# 9   food.safety@bexley.gov.uk
# 10  food.safety@bexley.gov.uk
#
#                                                scores  SchemeType  \
# 0   {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2   {'Hygiene': None, 'Structural': None, 'Confide...        FHRS
# 3   {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4   {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 5   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6   {'Hygiene': 10, 'Structural': 10, 'ConfidenceI...        FHRS
# 7   {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 8   {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 9   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 10  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                               geocode RightToReply  \
# 0   {'longitude': 0.126010000705719, 'latitude': 5...
# 1       {'longitude': 0.12601, 'latitude': 51.440986}
# 2    {'longitude': 0.1279308, 'latitude': 51.4443147}
# 3    {'longitude': 0.1256438, 'latitude': 51.4421709}
# 4      {'longitude': 0.125161, 'latitude': 51.442225}
# 5      {'longitude': 0.125161, 'latitude': 51.442225}
# 6      {'longitude': 0.125161, 'latitude': 51.442225}
# 7      {'longitude': 0.125161, 'latitude': 51.442225}
# 8      {'longitude': 0.124132, 'latitude': 51.442981}
# 9    {'longitude': 0.1315445, 'latitude': 51.4517582}
# 10  {'longitude': 0.132618993520737, 'latitude': 5...
#
#        Distance NewRatingPending  \
# 0   4644.027787            False
# 1   4644.027764            False
# 2   4644.079764            False
# 3   4644.084591            False
# 4   4644.104196            False
# 5   4644.104196            False
# 6   4644.104196            False
# 7   4644.104196            False
# 8   4644.169480            False
# 9   4644.220973            False
# 10  4644.242415            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links
# 0   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [11 rows x 28 columns]

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

#degree_search = 0.01
#latitude = 0.08384000
#longitude = 51.49014200

#query ={
    "RatingValue": 5,
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
#}
#sort = [("scores.Hygiene", -1)]
#limit = 15

# Print the results
#results = establishments.find(query).sort(sort).limit(limit)
# Convert result to Pandas DataFrame

# %%
# Convert result to Pandas DataFrame
#documents = list(establishments.find(query).sort(sort).limit(limit))
#df = pd.DataFrame(documents)
#df.head(11)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    # 1. Match establishments with a hygiene score of 0
    {"$match": {"scores.Hygiene": 0}},
    
    # 2. Group by Local Authority
    {"$group": {
        "_id": "$LocalAuthorityName",  # Group by Local Authority
        "count": {"$sum": 1},  # Count the number of establishments in each Local Authority
        "establishments": {"$push": "$BusinessName"}  # Collect the names of establishments
    }},
    
    # 3. Sort by count of establishments in descending order (highest to lowest)
    {"$sort": {"count": -1}}  # -1 for descending order
]
# Execute the aggregation pipeline
results = establishments.aggregate(pipeline)

# Print the number of documents in the result
result_list = list(results)  # Convert the aggregation cursor to a list
print(f"Number of Local Authorities with establishments having a hygiene score of 0: {len(result_list)}")

# Print the first 10 results
for result in result_list[:10]:
    pprint(result)
# Out:
# Number of Local Authorities with establishments having a hygiene score of 0: 55
# {'_id': 'Thanet',
#  'count': 1130,
#  'establishments': ['Tunnels Tea Shop',
#                     'Granville Theatre',
#                     'Toll Gate Kiosk',
#                     'Comfort Inn',
#                     'Whitecliff House',
#                     'Oak House',
#                     'Ramsgate Beach Kiosk',
#                     'Waterfront',
#                     'Sorbetto',
#                     'A La Turka',
#                     'Alexandra Restaurant',
#                     'The Little Vegan Food Place',
#                     'Food on Focus',
#                     'The Dog House & Grill',
#                     'The Nourish Bar',
#                     'Peters Fish Factory',
#                     'Royal Victoria Pavilion',
#                     'The Queens Head',
#                     'Perfecto Pasta and pizza',
#                     "Topp's Seafood",
#                     'Cannons of Ramsgate',
#                     'Thai Passion',
#                     'Alison Sea View Cafe',
#                     "Sam's Bar",
#                     'Royal Harbour Ramsgate Brasserie',
#                     'Enoteca',
#                     'The Oak Hotel',
#                     'Rokka',
#                     'The Glass House Tea Garden',
#                     'What Gwaan Limited',
#                     'Thanet Bowling Club',
#                     'Travellers in Italy',
#                     'Albion House Ramsgate',
#                     'Premier G & A Stores',
#                     'Dumpton Lodge',
#                     'Mother Goose Nursery',
#                     'Baker Street Cafe',
#                     'The Royal',
#                     'Gallegos Piri Piri',
#                     'Camden Arms',
#                     'D Suga Hut',
#                     'Clique Bar',
#                     'Little Ships',
#                     'Ramsgate Seafront Travelodge',
#                     'Coastal Bar Kent (Ltd)',
#                     'Crusties',
#                     'Buckmaster Home',
#                     "Gerry's Coffee & Art House",
#                     "Coco Latino & Clarey's Chocolates",
#                     'The Arch',
#                     'Ship Shape',
#                     'The Greek Arch',
#                     'Bodrum Kebab',
#                     'Archive Homestore',
#                     'Il Tricolore',
#                     'Ramsgate Tandoori',
#                     'Harbour Street Bar',
#                     'The Royal Fish Bar',
#                     'Taylor Meats Ltd',
#                     'The Goose',
#                     'Village Grill',
#                     'T.L.C',
#                     'RAFA Club',
#                     'Jah Jah',
#                     'Book Bodega',
#                     'Oban Supermarket',
#                     'Sunrise Cafe Restaurant',
#                     'Corbys Tearooms',
#                     'Wilkinson',
#                     'The Hovelling Boat Inn',
#                     'Mariners',
#                     'Keystore',
#                     'Crown',
#                     'The Home Front Tea Room',
#                     'Marc-Pierres Kitchen',
#                     'The Galley',
#                     'LA. Magnolia Ice Cream & Deli',
#                     'Thai Orchid',
#                     'La Magnolia',
#                     'Red Lion',
#                     'The York Arms',
#                     "Toni's Newsagents",
#                     'Papa George',
#                     'Curio Collectors Emporium',
#                     'Royal Temple Yacht Club',
#                     'Heaven and Hell Gifts',
#                     'Ramsgate Fish and Chips',
#                     'Victoria Off Licence',
#                     'Staple Stores',
#                     'Harbour Bakery',
#                     'Earl St Vincent',
#                     'Montefiore Arms',
#                     'Honeysuckle Inn',
#                     'Royal Harbour Hotel',
#                     'Hearth Restaurant',
#                     'The Lookout',
#                     'Sunrise Fish & Chips',
#                     'Zest Cafe & Bar',
#                     'KFC - Ramsgate',
#                     'Victoria Express',
#                     'Pizza 2 Night',
#                     'C and K Rileys Ltd',
#                     'Dirtee Feast',
#                     'Ravensgate Arms',
#                     'Costcutter',
#                     'BB Pasta & Pizza',
#                     'Moonshine Billys',
#                     'M & M Kebab Shop',
#                     'Good Fortune',
#                     'The Deal Cutter',
#                     'Souvlike - eat',
#                     'Iceland Foods Limited',
#                     'Subway',
#                     'Prentis',
#                     'Star Nergis',
#                     "Seaside's Restaurant",
#                     'Churchill Tavern',
#                     'Phoenix Care Homes Ltd',
#                     'Poundland',
#                     'Boots UK Ltd',
#                     'Holland & Barrett',
#                     'The Royal British Legion',
#                     'Bromley Lodge',
#                     'Ho Wong',
#                     'Union Ramsgate',
#                     'The Sun Club',
#                     'Elephant and Castle',
#                     'Harvest Health Foods',
#                     'The Corner Broadstairs',
#                     'Spice Garden',
#                     'Friends Fish and Chips',
#                     'Louisa Bay Cafe',
#                     'Sage Cafe Ramsgate',
#                     'Tesco',
#                     'Hereson News',
#                     'Star of China',
#                     'Coffee Hut',
#                     'Grub Hub',
#                     'Holy Trinity CEP School',
#                     'Viking',
#                     'W H Smith',
#                     'Kids Brighthouse',
#                     'R S Off Licence & Newsagents',
#                     'Ramsgate Masonic Centre',
#                     'The Falstaff',
#                     'Waitrose Ltd',
#                     'Queen Charlotte',
#                     "Dee's Cafe",
#                     'Broadstairs Sailing Club',
#                     'Tartar Frigate',
#                     'Main Refreshment Kiosk',
#                     'Wyatt and Jones',
#                     'The Pavilion',
#                     'Jetty Broadstairs',
#                     'Panorama Restaurant',
#                     "Queen's Kebab",
#                     'Former Aldi Store',
#                     'Bradstowe Lodge',
#                     'Cintra Hotel',
#                     'Cleveland House Ltd',
#                     'The Funicular Coffeehouse',
#                     'Golden Fish Bar',
#                     'Subway',
#                     'York Gate Ices',
#                     'Spencer Court Hotel',
#                     'Londis',
#                     'Lillyputt Mini Golf',
#                     'Bradstow School',
#                     'Addington Superstore',
#                     'Flavours By Kumar',
#                     'United Church',
#                     'The Modern Boulangerie',
#                     'The Charles Dickens',
#                     'Moffetts Kiosk',
#                     'Kebbells',
#                     'Clarendon & Chatham House Sixth Form Centre',
#                     'Chiappinis Coffee Shop',
#                     'Bandstand Kiosk',
#                     'Cafe Loki',
#                     'Neptunes Hall',
#                     'Harpers Wine Bar',
#                     'The Old Curiosity Shop',
#                     'Artfuls',
#                     'West Cliff Service Station',
#                     'International Food Store',
#                     'Happily Ever Afters',
#                     'Royal Albion Hotel',
#                     "Eats 'n' Beats",
#                     'Ethelbert Childrens Services',
#                     'The Hive Cafe',
#                     'St Ethelberts Roman Catholic Primary School',
#                     'Costa Coffee',
#                     "St George's Community Meal",
#                     'DOS',
#                     'The Table',
#                     'St Ethelberts Breakfast Club',
#                     'Stone Bay Montessori & Beach School',
#                     'La Zia Maria',
#                     'New China Inn',
#                     'Be Me Tea Limited',
#                     "Veg'N Out",
#                     'Siam Kitchen',
#                     'The George Inn',
#                     'The Mermaid Fish & Chips Restaurant',
#                     'Aqua 43',
#                     'Beaches Cafe Bar',
#                     "Seggari's",
#                     'Seafarer Restaurant',
#                     'The Chapel',
#                     "Bessie's Tea Parlour",
#                     'The Dolphin Lounge Bar',
#                     'Osteria Posillipo',
#                     'Clarendon House Grammar School',
#                     'Sardinia',
#                     'Samworth & Mee',
#                     "Raindell's",
#                     'The Sea Lounge',
#                     'Smokehouse',
#                     'Prezzo',
#                     'Albarino Tapas Restaurant Bar',
#                     'The Racing Greyhound',
#                     'The Pickled Herring',
#                     'Macies Bar',
#                     'The Dining Room',
#                     'The Gardners Retreat Restaurant',
#                     'Reign Bar & Lounge',
#                     'Wrotham Arms',
#                     'Tesco',
#                     'Bedford Inn',
#                     'Thanet Childcare Ltd',
#                     'Smiths Coffee Bar',
#                     'Rueanthai Shop',
#                     'The Little Sicilian',
#                     'Thai Four Two',
#                     'Helter Skelter Nursery',
#                     'Kyoto Sushi & Grill',
#                     'Golden Fortune',
#                     'Rooms at Number One',
#                     'Ramsgate Small Boat Owners Assoc',
#                     'Royal Naval Association',
#                     'Premier',
#                     "Sancho's",
#                     'Best Fish & Chips',
#                     'Please Sir',
#                     'The Prince Albert',
#                     'Pork & Co Limited',
#                     'Star of the Sea',
#                     'The Crown',
#                     'The Old Bakehouse',
#                     "Ed's Cafe",
#                     'Iceland Foods Limited',
#                     'Londis',
#                     'J Prentis Fruiterers & Greengrocers',
#                     'Premier',
#                     'Belvidere Place',
#                     'Rose of England',
#                     'Queens Road Baptist Church',
#                     'Victory News',
#                     'Beano Cafe',
#                     'Copperfields B & B',
#                     'Broadstairs House',
#                     'The Counting House',
#                     'East Kent College',
#                     'Crusties Bakery',
#                     'Chatham House & Clarendon House',
#                     'CCCP Restaurant',
#                     'Oriental Chef',
#                     'Montessori Nursery',
#                     'The Devonhurst',
#                     'Papa Johns',
#                     'The Kent School of English',
#                     'St Lukes Stores',
#                     'Fish Inn Ltd',
#                     'Ramsgate Care Centre',
#                     'Pop-In',
#                     'Brenan House',
#                     'The Ramsgate Balti Takeaway',
#                     'Spice Fusion',
#                     'Mayflower Take-away',
#                     'The Townley',
#                     'Explorers',
#                     'The Curry House',
#                     'Priory County Infants Breakfast Club',
#                     'Priory County Infant School',
#                     'Golden Fortune',
#                     "Sinatra's",
#                     'Crescent Stores',
#                     'East Kent Arms',
#                     'Co - Op Welcome',
#                     'Play Wise',
#                     'St Lukes Parish Hall',
#                     'Dumpton Post Office',
#                     'Ramsgate Sports Centre',
#                     'The Odds',
#                     'Asda Stores Limited',
#                     'The Salvation Army',
#                     'The Boating Pool',
#                     'Ramsgate Croquet Club',
#                     'The Boating Pool',
#                     'Mr lemonheads',
#                     'Christ Church Junior School',
#                     'Creta',
#                     'Kope & Loko',
#                     "Houdini's Magic Bar Ltd",
#                     'Co-operative Food',
#                     'Cafe Grill',
#                     'Roostys Bakery',
#                     'Broadstairs & St Peters Bowling Club',
#                     'South Eastern Tavern',
#                     'Hotel De Ville',
#                     'Conqueror Alehouse',
#                     'China City',
#                     'Cardak Meze & Grill',
#                     'Chef & Butcher',
#                     'Keele House',
#                     'Pizza Hut',
#                     'Broadstairs Kebab',
#                     'Vale Tavern',
#                     'Bradstow Mill',
#                     'Mind The Gap',
#                     'Stone Bay School',
#                     'Aysan Kebab Pizza',
#                     'Londis',
#                     'Langmead Guest House',
#                     'Thanet Early Years Project',
#                     'Beano Cafe',
#                     'Green Coffee House and Wine Bar',
#                     'Newlands County Primary School',
#                     'Newlands CP School Breakfast Club',
#                     'Broadstairs Cricket Club',
#                     'Lucky House',
#                     'St Mildreds County Primary School',
#                     'Salt of the Earth',
#                     'STB Pizza',
#                     'Premier',
#                     "Daa's Thai Diner",
#                     'Station Fish Bar & Grill',
#                     'Lawns',
#                     'Ramsgate Kebab',
#                     'Thanet Squash Rackets Club',
#                     'The Pines',
#                     'Wantsum Lodge',
#                     'Ashdene',
#                     'St Lawrence College',
#                     'Fruits De Mer',
#                     'Wellesley House School',
#                     'Winon',
#                     'Naughty But Nice',
#                     'The Beano Cafe',
#                     'Best One Express',
#                     'Dream Kitchen Kebab House',
#                     'Rent A Bar Units 123',
#                     'Haddon Dene School',
#                     'The Royston Micropub',
#                     'Broadstairs English Centre',
#                     'Broadstairs & St Peters Comrades Clu',
#                     'St Lawrence Bowls Club',
#                     'West Dumpton Stores',
#                     'Dou Dou Chinese',
#                     'Viaduct Stores',
#                     'Upton Junior School',
#                     'Budgens Local',
#                     'The Ramsgate Club',
#                     'The Square Dozen',
#                     'Yummy Chinese Takeaway',
#                     'Thanet Winter Shelter',
#                     'The Flying Horse',
#                     'ChristChurch School Breakfast Club',
#                     'Pie Factory',
#                     'Australian Arms',
#                     'Fledglings Nursery School',
#                     'Breakfast & After School Club',
#                     'St Josephs School',
#                     'The Albion Inn',
#                     'The Sir Stanley Gray',
#                     'Belle Vue Tavern',
#                     'Pumpkin',
#                     'Foliage plants',
#                     'Delicious Fish Bar',
#                     'St Lawrence Local',
#                     'St Lawrence Tandoori',
#                     'Sexy Burger',
#                     'Tesco',
#                     "Domino's Pizza",
#                     'Bargain Booze',
#                     'The Four Candles Alehouse',
#                     'St Lawrence Tavern',
#                     'Tycoon',
#                     'Thanet Kebab & Pizza',
#                     'St Laurence In Thanet Junior Academy',
#                     'The Lanthorne',
#                     'St Laurence Breakfast Club',
#                     'New Jumbo Chinese Takeaway',
#                     'The Pavilion Cafe',
#                     'Wychdene',
#                     'The Learning Tree',
#                     'Chilton County Primary School',
#                     'Royal Harbour Academy',
#                     'Foreland Fields School',
#                     'Thanet Wanderers',
#                     'Red Arrows Club',
#                     'Joss Bay Cafe',
#                     'Barbies Playschool And Selwyn House Nursery',
#                     'Royal British Legion',
#                     'Charles Dickens School',
#                     'Tiny Treasures Day Nursery',
#                     'Bromstone County Primary School',
#                     'Rydal Mini Mart',
#                     'North Star Off Licence',
#                     'Kent Residential Care Home',
#                     'Housing 21',
#                     'The Corner Coffee House',
#                     'Buttons Pre-School (Fegans)',
#                     'Port Regis Montessori Nursery',
#                     'Crusties',
#                     'Dane Court Grammar School',
#                     'Under 1 Roof Kids Thanet',
#                     'Stewarts Cafe',
#                     'The Windmill Pub',
#                     'Port Regis Nursing Home',
#                     'Blue Apple Contract Catering',
#                     'Newington Fish Bar',
#                     'Extended Day/Breakfast Club',
#                     'St Peter In Thanet Junior School',
#                     'Staple',
#                     'The White Swan',
#                     'Golf Club Restaurant',
#                     'Halfway House Cafe',
#                     'Ramsgate Brewery Ltd',
#                     'May King',
#                     'Best Moon Shop',
#                     'McColls',
#                     'Wholefood Earth',
#                     'Village Newsagents',
#                     'Callis Grange Breakfast Club',
#                     'Rams News',
#                     'Callis Grange County Primary School',
#                     'Newlyn House Residential Home',
#                     'Yard of Ale',
#                     'The Red Lion',
#                     'St Peters Stores',
#                     'Hogman Family Butchers',
#                     'Milk & More',
#                     'Pizza Go Go',
#                     'Pizza Place',
#                     'Pizza Alforno',
#                     'Ramsgate Arts School',
#                     'De Flame',
#                     'Morliss Fast Food',
#                     'St Peters Fish Bar',
#                     'Asda Stores Limited',
#                     'New Asia',
#                     'Peninsula',
#                     'Customer Restaurant',
#                     'Panku Broadstairs',
#                     'Shell Royal Oak',
#                     'Sense',
#                     'Newington Community Primary School',
#                     'Newington Community Centre',
#                     'Tandoori Express',
#                     'Lunch Club',
#                     'Co Operative Pioneer Store',
#                     'Sexy Burger',
#                     'Copperfields',
#                     'Peckish',
#                     'McDonalds Restaurants Ltd',
#                     'Scott-Dogs Mobile',
#                     'Dame Janet Breakfast Club',
#                     'Dame Janet Primary Academy Upper School',
#                     "Shorty's Nursery",
#                     'Botany Bay Beach Kiosk',
#                     'Northwood Club',
#                     'Hare & Hounds',
#                     'Mr Chips',
#                     'Elizabeth Pizza',
#                     'Best One',
#                     'Chun Chun',
#                     'Sycamore Stores',
#                     'Cabin Cafe',
#                     'The Cafe',
#                     'Tesco Ramsgate Manston',
#                     'Fosters',
#                     'Spar',
#                     'The Hook Up - Jayar',
#                     'Botany Bay Hotel',
#                     'Kingsgate Newsagents',
#                     'St Georges Secondary School',
#                     'Fairport Care Services',
#                     'The 19th Hole',
#                     'Barbies Footsteps',
#                     'The Stylish Ice Cream Co',
#                     'The Range',
#                     'Revolution Skate Park',
#                     "Dee Dee's Cafe",
#                     'Lidl',
#                     'The Sticky Wickett Sports Bar',
#                     'The Royal Harbour Acadamy',
#                     'The Shop on The Hill',
#                     'The Drinkshop.com Ltd',
#                     'Urban Grillaz',
#                     'Wholefood Earth Ltd',
#                     'Bannatynes Health Club',
#                     'SS Machinery UK',
#                     'Pegwell Bay Service Station',
#                     'Harris & Hoole Cafe',
#                     'The Cafe',
#                     'Tesco Extra',
#                     'The Gents Lodge',
#                     'Laleham Gap School',
#                     "Taddy's Barn Tea Room",
#                     'St Phillips Church',
#                     'Fairways Kitchen',
#                     'Priory Group Ltd',
#                     'The Martins',
#                     'Ebbsfleet Golf Centre',
#                     'Sainsburys',
#                     'The Canterbury Bell',
#                     'The Laughing Barrel',
#                     'McDonalds',
#                     'Lotus Garden',
#                     'Co-operative',
#                     'Palm Bay Fish Bar',
#                     'Premier Convenience Store',
#                     'Costa Coffee Drive Thru',
#                     'The Tenth',
#                     'Iceland Food Warehouse',
#                     'Poundstretcher',
#                     'B & M Stores',
#                     'Pizza Hut Restaurant',
#                     'Poundland',
#                     'Shop',
#                     'Dunelm Mill',
#                     'Wilkinsons',
#                     'Ask',
#                     'Thai Village Restaurant & Bar',
#                     'Grosvenor Casino',
#                     'Coffee Corner',
#                     'Vue Cinema',
#                     'Travelodge',
#                     'Mecca Bingo',
#                     'Boots UK Ltd',
#                     'Marks & Spencer Plc',
#                     'Costa Coffee',
#                     "Frankie & Benny's",
#                     'Subway',
#                     "Nando's",
#                     'Greggs',
#                     'Cafe Nero',
#                     'WH Smith',
#                     'Bella Italia',
#                     'CUP (Mobile)',
#                     'The Garden Gate Cafe',
#                     'All sorts of sweets and treats',
#                     'Kaspars',
#                     'Big Dees Fried Chicken',
#                     'Sunshine Pre-School',
#                     'Holy Trinity Cafe & Church Hall',
#                     'Cowley Rise Store',
#                     'Toby Carvery Thanet',
#                     'Hooden Horse',
#                     'Smokey Banditos',
#                     'Madison House',
#                     'Mulberry Court',
#                     'Farm Foods Ltd',
#                     'The Wheatsheaf',
#                     'Star Lane Stores',
#                     'Burger King Uk Ltd',
#                     'St Augustines Golf Club',
#                     'The Chai Stop',
#                     'Great Oaks Small School',
#                     'Meadows Nursery & Riverbank Club',
#                     'Millmead Early Years Centre',
#                     'Palm Bay Primary',
#                     'Northdown CP School Main Kitchen',
#                     'Just The Ticket Cafe',
#                     'The Crafty Little Cakery',
#                     'Jolly Farmer',
#                     'St Anthonys School',
#                     "The Avenues's  Montessori Nursery",
#                     'Home Bargains',
#                     'Holly Lane Fish Inn',
#                     'Cliftonville County Primary School',
#                     'The Village Pantry',
#                     'Premier',
#                     'Holly Lane Post Office & Stores',
#                     "Chicken Stop/Fat Daddy's",
#                     'The Lounge',
#                     'Global Generation Church',
#                     'Family Choice Mini Market',
#                     'Dane Valley Fish Bar',
#                     'Windmill Community Allotment Project',
#                     'Madre',
#                     'Bradgate Social Club',
#                     'Shell Margate Service Station',
#                     'Brothers Pizzeria',
#                     'TNS',
#                     'Tesco',
#                     'Yoakley House',
#                     "Aunty T's Kitchen",
#                     'Palm Bay Cafe',
#                     'Claremont Care Home',
#                     'Nazar Fish Bar',
#                     'Treetops Residential Home',
#                     'Redcot Lodge',
#                     'The Avenues Trust',
#                     'Tiarrah Pizza Bar',
#                     'Sense',
#                     "Gloria's Lounge & Cafe",
#                     'Pagoda Chinese T/A',
#                     'Northdown Pharmacy',
#                     'MFC',
#                     "Let's Go Pizza",
#                     'Jet Ski World Cafe',
#                     'Drapers Mill County Primary School',
#                     'Drapers Mill Breakfast Club',
#                     'TNS Local',
#                     'Maltreath',
#                     "Vera's",
#                     'Warwick Guesthouse',
#                     "Eddy's Fried Chicken Kebab",
#                     'Vinnys Cafe',
#                     'Skinny Dip Coffee',
#                     'Urchin Wines',
#                     'Approach Road Mini Mart',
#                     'International Food Centre',
#                     'The Oval Bandstand And Lawns',
#                     'Thanet Indoor Bowls Centre',
#                     'Graywood Care Home',
#                     'Green Gables',
#                     'R & Z Limited',
#                     'Batchelors Patisserie',
#                     'R & Z Ltd Cafe',
#                     'Aroma Cafe',
#                     'Cafe Kussan',
#                     'Walpole Bay Hotel',
#                     'Moylers',
#                     'The Tap Room',
#                     'The Bangkok Thai',
#                     'Costa Coffee',
#                     'Little Oaks Nursery',
#                     'QEQM Catering',
#                     'Stingray Drinks',
#                     'The Spencer Private Hospital',
#                     'Gresham Residential Home',
#                     "Ouma's Kitchen",
#                     'Aquarius Lodge',
#                     'Summerville Residential Home',
#                     'Pilgrims Hospice',
#                     'Cafe Continental',
#                     'ISS Mediclean Ltd',
#                     'Kent & Med NHS & Social Care P Trust',
#                     'TR Convenience Store',
#                     'The Belle Vue Tavern',
#                     "Kawa's Desserts",
#                     'Clifton Superstore - Premier',
#                     'Northdown Road Snooker Club',
#                     'Kebabish',
#                     'The Grain Grocer',
#                     'Lesters Pub & Restaurant',
#                     'Churchill Contract Catering, RADISH',
#                     'Cliftonville Outdoor Bowls Club',
#                     'Express Kebab',
#                     'International Mini Market',
#                     'Tom Thumb Theatre',
#                     'The Willows Care Centre',
#                     'Grosvenor Court Care Limited',
#                     'North Lodge',
#                     'Smiths Court Hotel Ltd',
#                     'Lick & Chew Sweet Supplies',
#                     'The Albion Rooms',
#                     'Rosslyn Court',
#                     'DWG Meat & Pies',
#                     'Days Supermarket',
#                     'Thanet Quality Foods',
#                     'The Lord Byron',
#                     'Tasty Kebab',
#                     'One Stop Stores',
#                     'Pasha',
#                     'TBS Pop UP',
#                     'Brightstart Nursery',
#                     'Cliffs',
#                     'EHIS Groceries',
#                     'Secret Spices',
#                     '101 Social Club',
#                     'Happy Cafe & Family Restaurant',
#                     "Henri's Pizzeria",
#                     'Fireaway Margate',
#                     "Andrew & Jill's General Store",
#                     'Baba Kebab House',
#                     'Premier Express Mini Mart',
#                     'Alfies Fish Bar',
#                     'Bayleaf Indian Curry House',
#                     'Ashcroft House',
#                     'St Gregorys Catholic Primary School',
#                     'St Gregorys Breakfast Club',
#                     'My Nursery',
#                     'The Oxford',
#                     'Salmestone County Primary School',
#                     'First Steps Nursery',
#                     'Yummy Thai',
#                     'Thanet Society of Druids Social Club',
#                     'New Life Family Church',
#                     'St Peters Home',
#                     'Dalby Cafe',
#                     'The Mulberry Tree',
#                     'Eata Pizza',
#                     'Bowling Club',
#                     'Dane Park Kiosk',
#                     'Al Madinah Foods',
#                     'Kebab House',
#                     'Resul Retail Ltd',
#                     'The Cliff',
#                     'Townsend Montessori Margate',
#                     "St Peter's Sausages",
#                     'Margate Leisure Centre',
#                     'Kitchen Social & Cookery Club cic',
#                     'Olympia Cafe',
#                     "Bugsy's Bowling Centre",
#                     'Mont Calm',
#                     'Faith in Strangers',
#                     'Mar Mar',
#                     'St Johns Community Centre',
#                     'Londis',
#                     'Thanet Express',
#                     'The Riz Convenience Store',
#                     'Shottendane Nursing Home',
#                     'We Are Here',
#                     'K G Winters',
#                     'The Master Cook',
#                     'Margate Indian Spice',
#                     'Sherwood Hotel',
#                     'Homewok Chinese Takeaway',
#                     'Quart in a Pint Pot',
#                     'Tivoli Cafe',
#                     'Riz Restaurant',
#                     'The Princess of Wales',
#                     'Costcutter',
#                     'Holy Trinity And St Johns C Of E Primary School',
#                     'Lawrence Stores',
#                     'Ty - 8',
#                     'Margate Family Shopper',
#                     'The Best Beano Cafe & Restaurant',
#                     'Six Bells Children Centre',
#                     'Poundstretcher Warehouse',
#                     'The London Tavern',
#                     'Theatre Royal',
#                     'The Cliff Bar',
#                     'Thanet Tasty Chicken',
#                     'Haeckels',
#                     'Forts Cafe',
#                     'Daisy',
#                     'The Reading Rooms',
#                     'Bar Nothing',
#                     'English in Margate',
#                     'The Salvation Army',
#                     'Cliftonville Off Licence',
#                     'Age UK  Thanet Ltd',
#                     'Kent Catering Company',
#                     'Mia Papas Kitchen',
#                     'Cambridge Villa Supported Living',
#                     'Super Pizza',
#                     'The Punch and Foody',
#                     'The Margate Caves Cafe',
#                     'Storeroom',
#                     'George Burgers',
#                     'McDonalds',
#                     'Sheldons',
#                     'Key Store Off Licence',
#                     "Gadd's Food & Drink",
#                     'Costcutter',
#                     "Widget's Toys",
#                     'Rose in June',
#                     'Milk and Cookie',
#                     'Winter Gardens',
#                     'Bay Guest House',
#                     'Curve Coffee Store',
#                     'The Pie Shop',
#                     'Infinity Coffee House',
#                     'Iceland Foods Limited',
#                     'Burger Bar',
#                     'Victoria Hotel Ltd',
#                     'The Hartsdown',
#                     'The George & Heart',
#                     'Palms Pizza',
#                     'C & S News',
#                     'Costa Coffee',
#                     'Kellys Sweets & Treats',
#                     'Greggs',
#                     'Elsewhere',
#                     'Poundland',
#                     'Modern Provider',
#                     'The New Odds Club',
#                     'Subway',
#                     'Seaside Cake Parlour',
#                     'Scissortail Ltd',
#                     'Edessa',
#                     'Margate Lawn Tennis Club',
#                     'Kawa',
#                     'The Little Fish Cafe',
#                     'Terrance House',
#                     'South Garden',
#                     'Tops Pizza',
#                     'Carbeez Jerk Chicken Takeaway',
#                     "Franklin's",
#                     'Giorgios',
#                     'Love Cafe',
#                     'Margate Masonic Lodge',
#                     'Cafe Darcy',
#                     'Silver Slipper Performing Arts Schoo',
#                     'Wig and Pen',
#                     "Bow's Kitchen",
#                     'Mullins Brasserie',
#                     "Ralph's",
#                     'The Britannia',
#                     'New Street Bistro',
#                     'Mama Jinny Thai Kitchen',
#                     'Beano Cafe & Family Restaurant',
#                     'Cafe de China',
#                     'Clock Tower Kebabs',
#                     'Our Kitchen',
#                     "L'Olivo",
#                     'Papa Johns',
#                     'Hantverk & Found',
#                     'The Clockwork Cocktail Company Ltd',
#                     'KFC - Margate',
#                     'Sundowners',
#                     'Kookidoe',
#                     "Olby's Soul Cafe",
#                     'Margate Express',
#                     'Zen by the Sea',
#                     'The Margate Bookshop',
#                     'Ramsay & Williams Ice Cream Bar',
#                     'The Lifeboat Ale and Cider House',
#                     'The Bulls Head',
#                     'Wildes',
#                     'The Greedy Cow',
#                     'Bottega Caruso, The Crown Gallery',
#                     'Masala Gate',
#                     'Beach Treats',
#                     'Alexandria Cafe',
#                     'Life is a Beach',
#                     'Waverley House',
#                     'Barnacles',
#                     'The Greek Kitchen',
#                     'Brens Diner & Bus',
#                     'Uncle Yupy',
#                     "Master Foody Moody's",
#                     "Gina's Old Bakery",
#                     'Jaffna South Indian',
#                     'Pan Asian Cuisine',
#                     'Breens Sweets',
#                     "Mae's Bar",
#                     'Mamma Mia Pizzeria',
#                     'MICommunity Shop',
#                     'Mannings Seafood',
#                     'The Little Prince',
#                     'Thao Thao Kitchen',
#                     'Lulus Gelato limited',
#                     'Khmer Kitchen @',
#                     'Harbour Cafe Bar',
#                     'Peters Fish Factory',
#                     'The Med',
#                     'The Margate Coffee Shed',
#                     'The Ocean Lounge',
#                     'SLAB',
#                     "Charlie's",
#                     'Cafe G',
#                     'J D Convenience Store',
#                     'Beet Bar',
#                     'Sands Hotel Margate Ltd',
#                     "Angela's of Margate",
#                     'Bowl Island ltd',
#                     'Big Shot',
#                     'The Glass Jar',
#                     'Fez',
#                     "Domino's Pizza",
#                     'Buoy and Oyster',
#                     'Little Swift',
#                     'Wetherspoons',
#                     'The Two Halves Margate',
#                     'Fond Coffee',
#                     'O Vesu Limited',
#                     'Oceans',
#                     'Rad Burger',
#                     'The Sweet Factory',
#                     'Cinque Ports',
#                     'Sands Restaurant & Cafe Bar',
#                     'Sunset Rock Shop',
#                     'The Candy Stop',
#                     'Kids Mayhem Clubworld',
#                     "Dory's",
#                     'Marine Express - Londis',
#                     'Pamela at The Turner Contemporary',
#                     'Imperial Lounge',
#                     'Great British Pizza Company Ltd',
#                     'Looking Ahead - Tea Rooms',
#                     'Hartsdown Academy',
#                     'Barletta',
#                     '13 Fitness',
#                     'Manor House Nursery School',
#                     'Atlantis Fish & Chips',
#                     'Guest House',
#                     'Hartsdown Leisure Centre',
#                     'Sea Shed',
#                     'Minster Village Hall',
#                     'Nelson Park Riding Centre',
#                     'Dive',
#                     'The Sargasso',
#                     'The Lighthouse Bar',
#                     'The Harbour Arms',
#                     'Brewers Fayre',
#                     'Coffee Station',
#                     'McDonalds Restaurant And Drive Through',
#                     'The Bell Inn',
#                     'Grub Hub',
#                     'Buy Whole Foods on Line',
#                     'The Pink House',
#                     'Pan Asian Cuisine',
#                     'Llee House',
#                     'Bright Star Nursery',
#                     'Sure Start',
#                     'The Bus Cafe',
#                     'Pork And Company Limited',
#                     'Staple',
#                     'Somerville Hotel',
#                     'Garlinge Primary School And Nursery',
#                     'Garlinge Junior Breakfast Club',
#                     'Garage Coffee',
#                     'The Kent Larder',
#                     'Nayland Rock Hotel',
#                     'Yummy Yummy',
#                     'Charcoal Grill',
#                     'Ali Raj',
#                     'Pizza 2Night',
#                     'Liquor Locker',
#                     "Archie's Fish and Chips",
#                     'Hair Of The Dog',
#                     'Casa Pizzeria & Cafe',
#                     'Westbrook Food and Wine',
#                     'Ales Of The Unexpected',
#                     'Westbrook Cafe',
#                     'Westbrook Convenience Store',
#                     'Minster Day Nursery',
#                     'Minster Primary School',
#                     'Kent Fresh',
#                     'Drink Margate',
#                     'Minster Kebabs',
#                     "Jemima's Tea Room",
#                     'China Chef',
#                     'The Salvation Army',
#                     'Kentish Sandwich Company',
#                     'The New Inn',
#                     'Westbrook Fish Bar',
#                     'Fifty 2',
#                     'Strokes Adventure Golf',
#                     'Tesco',
#                     'Costa Coffee Drive Thru',
#                     'Westbrook Club',
#                     'Amadeus Trattoria',
#                     'Garlinge Fish Bar',
#                     'Merlin Cafe',
#                     'Express By Holiday Inn',
#                     'Co Op Minster',
#                     'Westbrook Lodge Guest House',
#                     'Ivanhoe Avenues Group',
#                     'Garlinge Newsagents',
#                     'Smugglers Retreat Table Table',
#                     'Shaw Healthcare (FM Services)',
#                     'Royal British Legion Club',
#                     'Type One Style',
#                     "Barbara's Baps",
#                     "Mia's Cuisine",
#                     'Costcutter',
#                     'Flavours by Kumar',
#                     'Ibiza Fitness Food',
#                     'Rosedene Residential Home',
#                     'Marks & Spencer',
#                     'SPRY Craft Shots Ltd',
#                     'Sams Room Service',
#                     'Panda Chinese Take Away',
#                     'Blue Oceans',
#                     'The Hussar',
#                     'Birchington Vale',
#                     'Woodies Shop and Cafe',
#                     'The Westgate Care Centre',
#                     'Mermikides Community Centre',
#                     "Community Under 5's",
#                     'Westgate Community Centre',
#                     'Nourish Contract Catering Ltd',
#                     'St Crispins Breakfast Club',
#                     'Gordon Lodge',
#                     'Roxburgh House',
#                     'Avondale',
#                     "Millie's Beach Bar",
#                     "The St Mildred's Bay",
#                     'Little Brown Fairy Cake',
#                     'Windsor House',
#                     'Beano Cafe',
#                     'Beano Kebab',
#                     'Hot Wood Pizza',
#                     'J Prentis Greengrocers',
#                     'Co-op - Westgate',
#                     'Regency Tandoori',
#                     'The Best Beano Cafe',
#                     'St Augustines',
#                     'Lochaber Lodge',
#                     'The Maples',
#                     'Westgate on Sea Social Club',
#                     'Pats Pastys',
#                     'Cheeky Monkeys Preschool',
#                     "Ginger's",
#                     'Station Superstore',
#                     "Paul's Bar & Bistro",
#                     'The Corkscrew Off Licence',
#                     'Piggybank Day Nursery',
#                     'Krusty Kobb',
#                     'Quince',
#                     'Windsor House',
#                     'Staple Stores',
#                     'The Lodge',
#                     'Christchurch Lunch Club',
#                     'Eaton Lodge',
#                     'Best One',
#                     'The Chilterns',
#                     'Dadds Butchers',
#                     'Julias',
#                     'Westgate Town Council',
#                     'St Saviours School',
#                     'Food of love Thanet',
#                     'Carlton Cinema',
#                     'Golden Palace',
#                     'Westgate United Services Club',
#                     'Bake & Alehouse',
#                     'Fredericks Cafe',
#                     'Bethanys',
#                     'The Fish Inn',
#                     'New Friendly House',
#                     'Premier',
#                     'St Saviours Breakfast Club',
#                     'Ocean Swell Residential Home',
#                     "D'arcys Catering Limited",
#                     'St Michaels Nursing Home',
#                     'Bar Only',
#                     'Off the hook pizza',
#                     'Ursuline College',
#                     'Project 43',
#                     'Weddings & Events & Felicitys Cafe',
#                     'Quex Adventure Golf',
#                     'The Pearl Kitchen',
#                     'The White Stag',
#                     'Le Club the Foxhunter Park',
#                     'The King Ethelbert School',
#                     'The Swan by the Sea',
#                     'Quex Activity Centre',
#                     'Monkton County Primary School',
#                     'Quex Barn',
#                     'Quex Barn Pizza',
#                     "Monkton Under 5's Play group",
#                     'Finbars Restaurant',
#                     'West Bay Cafe',
#                     'The Cabin Eatery',
#                     'Principals',
#                     'Birchington CE Breakfast Club',
#                     'Noahs Ark Nursery',
#                     'Smugglers Restaurant',
#                     'Village Square Cafe',
#                     'Strawberry Fields',
#                     'The Cow Shed Bar & Grill',
#                     'New Dragon',
#                     'Martin McColls',
#                     'Birchington Club',
#                     'The Powell',
#                     'The Bottle Shop',
#                     "Domino's Pizza",
#                     'Par Cha Roen Thai Supermarket',
#                     'Shell Service Station Birchington',
#                     'Premier Stores',
#                     'Happy Nails',
#                     'Birchington Village Bakery',
#                     'Royal Dragon',
#                     "Wendy's Cafe",
#                     'Fishbone Grill',
#                     'All Saints Church Hall',
#                     'Birchington Fast Foods',
#                     'Pixie’s Birchington Ltd',
#                     'Co-op',
#                     'Springfield House',
#                     'Jay Express',
#                     'Birchington United Services Club',
#                     "Mandy's Deli",
#                     "Monty's",
#                     "Zara's",
#                     'Harbour Bakery & Driftwood Cafe',
#                     'The Cabin',
#                     'Highfield',
#                     'BVCA',
#                     'Golden Bridge',
#                     'Seaview Hotel',
#                     "Sainsbury's",
#                     'Blend Coffee Lounge',
#                     'Tandoori Nite',
#                     'The Wheel Alehouse',
#                     "BBL's",
#                     'R C Wale & Son',
#                     'The Co-operative',
#                     'Turkvaz',
#                     'Minnis Bay Fish & Chips',
#                     'The Parlour',
#                     'Christies',
#                     'Spencer House Nursing Home',
#                     'Birchington on Sea Bowls Club',
#                     'Beach House',
#                     'Grenham Bay Court',
#                     'Edgecliff Boutique B & B',
#                     'Twentieth Century B&B',
#                     "Joe's",
#                     'Best One',
#                     'The Bouncing Bomb Cafe',
#                     'Feelgoodmotherhood',
#                     'The Bay Fish Bar',
#                     'The Windshack',
#                     'Crown Inn',
#                     'The Waves Bar,Cafe, B & B Hotel  2',
#                     'Minnis Bay Sailing Club',
#                     'The Minnis Bar & Restaurant',
#                     'The Bay - VCT bikes',
#                     'Sun Inn',
#                     'St Nicholas At Wade C Of E Primary School',
#                     'Post Office',
#                     'Blackboard Schooling Support']}
# {'_id': 'Greenwich',
#  'count': 882,
#  'establishments': ['Black Boy Public House',
#                     'Bexley Foodbank',
#                     'The Pemberdeen Laser Cosmetic Clinic Ltd',
#                     'ISS Facility Services',
#                     'Assessment & Treatment Unit',
#                     'Cygnet Bostall House',
#                     'Breadline Catering Ltd',
#                     'Crafty Wizard',
#                     'Yasaka Sushi',
#                     'Alderwood Primary School',
#                     'NEW ELTHAM GRILL',
#                     'New Eltham Social Club',
#                     'Premier',
#                     'Eltham Green School Nursery Ltd',
#                     'The Bubble & Sausage',
#                     "Gill's eells",
#                     'CH&Co Group Ltd',
#                     'ISHA SPICE',
#                     'Ruchita Tandoori',
#                     'Lai Loi Street',
#                     'Pope Street Bar & Kitchen Limited',
#                     'Montbelle Primary School',
#                     'The Alpha Club',
#                     'Avery Hill Youth Hub',
#                     'Monkey Puzzle Eltham',
#                     'Village Nursery',
#                     '3rd Royal Eltham Scouts',
#                     'Churros Libre',
#                     'The Dome Eatery',
#                     'Student Union Village Shop',
#                     'Premium Off Licence',
#                     "Elsie's Pie N Mash",
#                     'Codfellas',
#                     'Dominos Pizza',
#                     'New Eltham Library Coffee Shop',
#                     'Abbey Wood Caravan and Motorhome Club',
#                     'Co-op Food',
#                     'Crafty Wizards Ltd',
#                     'CAFTAO',
#                     'Farmhouse Public House',
#                     'The Beehive',
#                     'Sunrise Takeaway',
# ...
#                     'Beam Guest House',
#                     'Brooklyn House',
#                     'Travelodge',
#                     'Toby Carvery',
#                     'Beeches Guest House',
#                     'Papa John',
#                     "Domino's Pizza",
#                     'Home Acre',
#                     'Jamrocks Caribbean Cuisine',
#                     'The Terrace',
#                     'Princes Theatre (Essex Hall)',
#                     'Sweets R Us',
#                     'Robbie Rascals Party Centre',
#                     'Mermaids Burger Bar',
#                     'Fairview',
#                     'Essex Fresh Start Independent School',
#                     'Regent House',
#                     'Haven Lodge',
#                     'Adelaide Guest House',
#                     'Sweet Street',
#                     'Playpalz Party and Softplay Centre Ltd',
#                     "Jenny's House",
#                     'Andos',
#                     'Creative Chefs',
#                     'CSC Ltd',
#                     'Body and Soul Food',
#                     'Aldersgate Welcome Inn',
#                     'Golden Plaice',
#                     'St Marks Care Home',
#                     'T Ann Cakes',
#                     'Bluebird Tearoom',
#                     'Aldi Stores Ltd',
#                     'Koekoek Restaurants Ltd',
#                     'Century Cinema',
#                     'Kingston House',
#                     'Mondial',
#                     'Costa',
#                     'Iceland',
#                     'Spring Lodge',
#                     'The Cavendish',
#                     'Bargain Hunters',
#                     'Hearty Pies',
#                     'Asda',
#                     "Big E's Diner",
#                     'TALCO INTERNATIONAL FOODS ( Tandoori Express)',
#                     'The Kaz Bar',
#                     '2 Hearts Catering',
#                     'Halfway House',
#                     'Nineteenth Catering at Clacton Golf Club',
#                     "Sai's Kitchen",
#                     'East of England Co-op',
#                     'Pizza Hut',
#                     'Eat One 8 One',
#                     'Clacton Conservative Club',
#                     "Amy's",
#                     'Londis',
#                     'Traditional Home Meals',
#                     'Burrsville Infant Academy',
#                     'Alton Park Junior School',
#                     'Queens Arms',
#                     'Comrades Sports and Social Club',
#                     'Seconds Out Gym Sandwich Bar',
#                     'Birch Hall Adventures',
#                     'Magdalen Close Hostel',
#                     'Clacton Ice Cream (2015) Ltd',
#                     'London Road Garage (Esso)',
#                     "Reg's",
#                     'Totally Scrumptious Cake Company',
#                     'St Marks & Hall',
#                     'Oakwood Infant School',
#                     'Subway',
#                     'Costa',
#                     'Home Bargains',
#                     'Booker Cash and Carry',
#                     'Just Spuds',
#                     'Asterbourne Chinese Takeaway',
#                     'The Chippy',
#                     'Stores',
#                     'Sun Yau',
#                     'CTC Freshway',
#                     'Almond Art',
#                     'Amazing Activities Limited',
#                     'Chestnut Grove Kindergarten',
#                     'East of England Co-op',
#                     "Gary's Fish and Chips",
#                     'Kiln Barn Stores',
#                     'Lidl',
#                     'Cafe On The Green',
#                     'United Services Club',
#                     'Childrens Respite Care Ltd',
#                     'Achieving Aspiration',
#                     'Fry Inn',
#                     'McColls',
#                     'Alexandra House',
#                     'J & J Wilson',
#                     'Family Shopper',
#                     'The Good Life',
#                     'Deli 141',
#                     "King's Arms",
#                     'Dovercourt House Care Home',
#                     'Tesco',
#                     'Reynolds Newsagents',
#                     'The Waterfront',
#                     'Peking Chinese Restaurant',
#                     'Tasty Takeaway',
#                     'KFC (Brook Retail Park)',
#                     'Tesco Bakery Counter',
#                     'Elior UK',
#                     'Tesco Deli Counter',
#                     'RB Stores',
#                     'Pieseas Chippy',
#                     'Iceland',
#                     'USA Fried Chicken',
#                     'Cabin Bakery',
#                     'Roberts Cafe \\& Bar Restaurant',
#                     'The Cats Whiskers',
#                     'LOCO Cafe \\& Pizzeria',
#                     'Treo Bar Café',
#                     'Old Bank Studios',
#                     'Shakers Bar',
#                     "Terry's Fresh Fish",
#                     "Peri's Mini Mart",
#                     "Jenny's Resource Ltd",
#                     'Langley House Harwich Ltd',
#                     'Cann Hall  Primary School',
#                     "St Joseph's Catholic Primary School",
#                     'New Bell Inn',
#                     'Inclusion Ventures',
#                     'Jaywick Community Resource Centre',
#                     'Tower Hotel',
#                     'Rainbow Cafe / Takeaway',
#                     'Pauls Mobile Restaurant',
#                     'Samuel Pepys Wine Bar',
#                     'Globe',
#                     'Thai Up at The Quay',
#                     'RNLI Sales Ltd',
#                     'Cafe On The Pier & Pier Seafoods',
#                     'Baked By The Sea',
#                     'Reedlands Farm',
#                     'St Clares Primary School',
#                     'ASDA',
#                     'Sir Martin Frobisher Academy',
#                     'ISS Facility Services Education',
#                     'Mr Cadburys',
#                     'Ravens Academy',
#                     'Harwich Sports Hall',
#                     'Lime Court Care Centre',
#                     'One Stop',
#                     'Nisa Local',
#                     'Don Thomson House',
#                     'Cottage Walk - Achieve Together',
#                     'Bockings Elm Post Office',
#                     'Brace Of Pistols',
#                     'Harwich School The Lighthouse Canteen',
#                     'Vines Service Station',
#                     'Woodrows Nursery',
#                     'The Wick Lodge Bar and Resturant',
#                     'Brain Injury Rehabilitation Trust',
#                     'Fryatt Hospital',
#                     'Rosebank Park',
#                     'Blue Garden Cafe',
#                     'Little Clacton Village Hall',
#                     'Sailor Boy Freehouse',
#                     'Sailor Boy Cafe',
#                     'East of England Co-op Foodstore',
#                     'Upper Dovercourt Post Office',
#                     'Sailor Boy Fish \\& Chip Shop',
#                     'All Saints School',
#                     'Edwards of Harwich',
#                     'Health & Happiness',
#                     'Dovercourt Grill',
#                     'Tipmalee',
#                     'Lifehouse',
#                     'Engaines Primary School',
#                     'Spring Meadow School House Nursery',
#                     'Morrisons Daily',
#                     'McDonalds',
#                     'Costa Coffee',
#                     'Morrisons',
#                     'The Mayflower Brewers Fayre',
#                     "Domino's Pizza",
#                     "Nemo's Sea Food",
#                     'Little Paddocks',
#                     'Slush Rush',
#                     'Caribbean Slush Hut',
#                     'Take Away Express',
#                     'Holiday Inn Diner',
#                     'Tudor Bar',
#                     'The Village Inn',
#                     'Dollys Pantry',
#                     'Tollgate Post Office',
#                     'NMK Newsagents',
#                     'Fry Fish and Grill',
#                     'Oakley Pharmacy',
#                     'Tendring Technology College',
#                     'The Fryatt Hotel \\& Bar',
#                     'One Stop',
#                     'Skippers',
#                     'Rolph Primary School',
#                     'Oakwood Plough Corner',
#                     'Simply Chocolate Fountains',
#                     'Vijil Catering',
#                     'Tamarind',
#                     'Ye Olde Cherry Tree',
#                     'Tesco',
#                     'Cloverwood General Store',
#                     'Quayside Cafe (Churchill Catering Ltd)',
#                     'Rose And Crown',
#                     'Two Village CofE (VC) Primary School',
#                     'Smoked Out BBQ',
#                     'Watershed Studios',
#                     'Priory Group',
#                     'The Village Chippy',
#                     'St Osyth Chuch of England Primary School',
#                     'Lime Trees',
#                     'White Hart',
#                     'Dukes Tea Room and Bistro',
#                     'St Osyth Butchers',
#                     'TLC Care Homes',
#                     'Creams \\& Coffee (Formley Eco Ice Creams)',
#                     'Cotchel Mobile Event Trailer',
#                     'St Osyth Preschool',
#                     'Brooke-lynne Farm Shop',
#                     "East Coast Pizza's Ltd",
#                     'White Heather Care',
#                     'Floral Days Cafe',
#                     'The Shy Pig',
#                     'Brokhowse',
#                     'TLC Care Homes',
#                     'Foresters Tavern',
#                     'Willow Park Resource Centre',
#                     'St Andrews Primary School',
#                     'Homestead Cabin Cafe',
#                     'Weeley Post Office',
#                     'Five Stacks Residential Home',
#                     'Gaunts Bakery',
#                     'Black Boy',
#                     'Stour Valley Organic Produce',
#                     'Grove Farm',
#                     'McDonalds',
#                     'MFG Weeley Service Station',
#                     'Tudor Restaurant',
#                     'Ford Barns',
#                     'The Fusilier',
#                     'Oaks',
#                     'Brewstar Coffee',
#                     'Wix Village Hall',
#                     'Waggon',
#                     'Orchards Holiday Village',
#                     'Burger King',
#                     'Show Bar and Papa Johns',
#                     'Bowling Green',
#                     'Rays Burgers',
#                     'The Rosebud',
#                     'Wix and Wrabness Primary School',
#                     'Wix and Wrabness Pre School',
#                     'Coach House Coffee Shop',
#                     'UCSC Ltd (University Community Sailing Club)',
#                     "BB's",
#                     'The Ferryboat Inn',
#                     'Ferry Boat Inn',
#                     'T\\&Cake',
#                     'The Cottage',
#                     'Raj Spice',
#                     "BWYC 'The Old Sail Loft'",
#                     'Fresh Cafe',
#                     'Bumbles Greengrocers',
#                     'Royal British Legion',
#                     'Brightlingsea Sailing Club',
#                     'S W Services',
#                     'Tesco',
#                     'Brightlingsea Play Centre',
#                     'Co-op Daily',
#                     'The Kings Head',
#                     'Brightlingsea Bowls Club',
#                     'Brightlingsea Infant School',
#                     'Brightlingsea Junior School',
#                     'Brightlingsea Community Centre Coffee Morning',
#                     'Tesco',
#                     'The Plough Inn',
#                     'China Palace',
#                     'Brightlingsea Community  Association',
#                     "Bateman's Tower Café",
#                     'Cafe Lido',
#                     'Great Bentley Primary School',
#                     'D Spence Family Butchers Ltd',
#                     "Big Al's Shack",
#                     'Restaurant 43',
#                     'Great Bentley Methodist Church & Hall',
#                     'Four Winds',
#                     'The Cherry Tree',
#                     'Oaklands',
#                     'Graham Watkins',
#                     'Corner Service Station',
#                     'Shell Corner',
#                     'Croft',
#                     'Cake - Quest',
#                     'Oaktree Manor',
#                     'Duck & Pheasant / Coot \\& Moorhen',
#                     'Fiveways Petrol Station',
#                     "Mac's Gourmet Hot Dogs",
#                     'East of England Co-op',
#                     'Ladybirds Pre-School',
#                     'Stuart Hazell (Ice Cream Mobile)',
#                     'Stuart Hazell (Burger Van)',
#                     'Stronvar',
#                     'Bamburgh House Ltd',
#                     'Futures',
#                     'Danshell Adult Healthcare',
#                     'Quenby Residential Home',
#                     'Black Jacket Events Ltd',
#                     'The Roscoe Cakery',
#                     "Sorano's Ltd",
#                     'Mouse House Bakes',
#                     'The Village Maid',
#                     'Bricklayers Arms',
#                     'Strangers Home',
#                     'The Old Ram and Hoggett Tearoom',
#                     'Bradfield News Limited',
#                     'Rostrum Cafe',
#                     'Baxter Storey - Penguin Random House',
#                     'Meadowcroft',
#                     'Alresford Family Support',
#                     'Larchcroft Trading Co Ltd',
#                     'The Court House',
#                     'Spar',
#                     'Solo Cheese Ltd',
#                     'Tara Traders',
#                     'Alresford Fish Bar',
#                     'Sizzlers',
#                     'Pointer Inn',
#                     'True Celebrations',
#                     'Mistley Norman Primary School',
#                     'Butterflys',
#                     'Elm House',
#                     "Becky's Butchers",
#                     'Heidi (TheStation Wagon)',
#                     'The Shed Cafe',
#                     "St George's C of E School",
#                     'Sunnymead Kitchen',
#                     'Beth George',
#                     'Swiss Farm Limited',
#                     'Mitchell Farm Shop',
#                     'Seven Rivers Cheshire Home',
#                     'Mistley Manor Care Home',
#                     'The Crown',
#                     'Tesco',
#                     'Select Catering',
#                     'Dragon House',
#                     'Market Field School',
#                     'Cafe Rio',
#                     'Hobsons Deli \\& Cafe',
#                     'Chilvers Fish Shop',
#                     'Stour Fruiterers',
#                     'Skinners Arms',
#                     'Elm Cottage',
#                     'Simply Thai',
#                     'Manningtree Grill and Pizza',
#                     'Sibbons Plant Hire',
#                     'East of England Co-op',
#                     'Ragmarsh Farm Burger Bar',
#                     'Highfields Primary School',
#                     'Busy Bees Kindergarten',
#                     'Honeycroft Post Office',
#                     'Stour View Stores',
#                     'Manningtree High School',
#                     'Lawford C of E Primary School',
#                     'Crumb & Brew',
#                     'Elmstead Primary School',
#                     'The Cupcake Oven',
#                     'Cake My Day',
#                     'Lawford Football Club',
#                     'The Hunger Cure',
#                     'Riverford Organic',
#                     'Craft Nurseries Coffee Shop',
#                     'Christines',
#                     'Elm Park Brain Injury Services',
#                     "St Mary's Primary School",
#                     'Orchard Barns Kindergarten',
#                     'The Bungalow',
#                     'Crown Inn',
#                     'Jubilee Cafe',
#                     'KFC Ardleigh',
#                     'KFC Ardleigh']}

# %%
pipeline = [
    # 1. Match establishments with a hygiene score of 0
    {"$match": {"scores.Hygiene": 0}},
    
    # 2. Group by Local Authority
    {"$group": {
        "_id": "$LocalAuthorityName",  # Group by Local Authority
        "count": {"$sum": 1},  # Count the number of establishments in each Local Authority
        "establishments": {"$push": "$BusinessName"}  # Collect the names of establishments
    }},
    
    # 3. Sort by count of establishments in descending order (highest to lowest)
    {"$sort": {"count": -1}}  # -1 for descending order
]

# Execute the aggregation pipeline
results = establishments.aggregate(pipeline)

# Convert the result to a list and then to a Pandas DataFrame
result_list = list(results)
df = pd.DataFrame(result_list)

# Display the number of rows in the DataFrame
print(f"Number of rows: {len(df)}")

# Display the first 10 rows of the DataFrame
df.head(5)
# Out:
# Number of rows: 55
#          _id  count                                     establishments
# 0     Thanet   1130  [Tunnels Tea Shop, Granville Theatre, Toll Gat...
# 1  Greenwich    882  [Black Boy Public House, Bexley Foodbank, The ...
# 2  Maidstone    713  [Ibi's Kitchen Limited, The Vine, OG Plants, K...
# 3     Newham    711  [Breakfree Respite Care, Babcock Beckton, The ...
# 4      Swale    686  [Elijah Retail - Greggs, Karimix UK Ltd, Trail...

# %%
# Convert the result to a Pandas DataFrame
#result_list = list(result)
#df = pd.DataFrame(result_list)

# Display the number of rows in the DataFrame
#print(f"Number of rows: {len(df)}")

# Display the first 10 rows of the DataFrame
#df.head(10)

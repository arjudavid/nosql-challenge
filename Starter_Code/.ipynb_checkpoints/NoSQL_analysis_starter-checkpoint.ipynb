# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
#Importing dependencies
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)

# Display the first document in the results using pprint
first_document = establishments.find_one(query)
pprint(first_document)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('678327394905d7d928297d5b'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame([first_document])

# Display the number of rows in the DataFrame
print("Number of rows:", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows: 1
#                         _id  FHRSID  ChangesByServerID  \
# 0  678327394905d7d928297d5b  110681                  0
#
#   LocalAuthorityBusinessID         BusinessName     BusinessType  \
# 0                     4029  The Chase Rest Home  Caring Premises
#
#    BusinessTypeID          AddressLine1 AddressLine2 AddressLine3  ...  \
# 0               5  5-6 Southfields Road   Eastbourne  East Sussex  ...
#
#                       LocalAuthorityWebSite       LocalAuthorityEmailAddress  \
# 0  http://www.eastbourne.gov.uk/foodratings  Customerfirst@eastbourne.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                          geocode RightToReply     Distance  \
# 0  {'longitude': 0.27694, 'latitude': 50.769705}               4613.888288
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [1 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName": {'$regex': "London"}, "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
count = establishments.count_documents(query)
print(f"Number of establishments with RatingValue >= 4 in London: {count}")

# Display the first document in the results using pprint
second_document = establishments.find_one(query)
pprint(second_document)
# Out:
# Number of establishments with RatingValue >= 4 in London: 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273a4905d7d928299779'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the result to a Pandas DataFrame
documents = list(establishments.find(query))
df = pd.DataFrame(documents)

# Display the number of rows in the DataFrame
print("Number of rows:", len(df))

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows: 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  6783273a4905d7d928299779   621707                  0
# 1  6783273a4905d7d928299a9c  1130836                  0
# 2  6783273a4905d7d92829a5e7   293783                  0
# 3  6783273a4905d7d92829b3e8  1315095                  0
# 4  6783273a4905d7d92829b3e9   294474                  0
# 5  6783273a4905d7d92829baf5   294900                  0
# 6  6783273b4905d7d92829dc00   293756                  0
# 7  6783273b4905d7d92829dfc8   878523                  0
# 8  6783273b4905d7d92829dfe0   293772                  0
# 9  6783273b4905d7d92829dfe1   295107                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000020749                      City Bar & Grill
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9  Restaurant/Cafe/Canteen               1
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                      London City Airport (Airside)
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                                London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8     {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Coordinates of "Penang Flavours"
latitude = 51.49014200
longitude = 0.08384000

# Define the search range (0.01 degrees for a small area)
degree_search = 0.01  

# Query to find establishments near Penang Flavours 
query = {"RatingValue": 5,
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
}

sort = [("scores.Hygiene", 1)]
limit = 5

# Search for nearby establishments
results = establishments.find(query)

# Print the results to see the nearby establishments
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '152 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.930146257832,
#  'FHRSID': 1069652,
#  'LocalAuthorityBusinessID': 'PI/000206841',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2020-10-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d568'),
#  'geocode': {'latitude': 51.4870351, 'longitude': 0.0927429},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1069652',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4646.946071297699,
#  'FHRSID': 695223,
#  'LocalAuthorityBusinessID': 'PI/000178842',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-11-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d58f'),
#  'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4646.95593107927,
#  'FHRSID': 1380578,
#  'LocalAuthorityBusinessID': '14425',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SE',
#  'RatingDate': '2021-11-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d59e'),
#  'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '130 - 132 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4646.965634598608,
#  'FHRSID': 694609,
#  'LocalAuthorityBusinessID': 'PI/000116619',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-08-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d5c6'),
#  'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Plumstead Manor Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4646.9740101340385,
#  'FHRSID': 695241,
#  'LocalAuthorityBusinessID': 'PI/000179088',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QG',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d5d4'),
#  'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '35 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Atlantic Fish Bar',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4646.974611855838,
#  'FHRSID': 694478,
#  'LocalAuthorityBusinessID': 'PI/000086506',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PR',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d5d6'),
#  'geocode': {'latitude': 51.4867296, 'longitude': 0.0912164},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '17 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.975587048333,
#  'FHRSID': 909912,
#  'LocalAuthorityBusinessID': 'PI/000201100',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PP',
#  'RatingDate': '2020-10-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d5d8'),
#  'geocode': {'latitude': 51.4871632, 'longitude': 0.0916256},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '6 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Greggs',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4646.987290353701,
#  'FHRSID': 694482,
#  'LocalAuthorityBusinessID': 'PI/000086551',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PP',
#  'RatingDate': '2021-06-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d5f6'),
#  'geocode': {'latitude': 51.4871406555176, 'longitude': 0.0912820026278496},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694482',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '18 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Tesco',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4646.987290353701,
#  'FHRSID': 695204,
#  'LocalAuthorityBusinessID': 'PI/000177985',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PP',
#  'RatingDate': '2020-10-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d5f7'),
#  'geocode': {'latitude': 51.4871406555176, 'longitude': 0.0912820026278496},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695204',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '107A Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Dosa & Sambal Express',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.999553676595,
#  'FHRSID': 1211907,
#  'LocalAuthorityBusinessID': '13217',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2020-07-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d61d'),
#  'geocode': {'latitude': 51.4877576, 'longitude': 0.091566},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1211907',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '12 - 14 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Abbi Wines',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.001583335365,
#  'FHRSID': 940026,
#  'LocalAuthorityBusinessID': 'PI/000177403',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PP',
#  'RatingDate': '2021-08-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d621'),
#  'geocode': {'latitude': 51.4871401, 'longitude': 0.0908895},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/940026',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '112 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Fineway Cash & Carry',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.016995291011,
#  'FHRSID': 694606,
#  'LocalAuthorityBusinessID': 'PI/000116584',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SJ',
#  'RatingDate': '2020-10-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d646'),
#  'geocode': {'latitude': 51.4876089, 'longitude': 0.0909382},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694606',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '101 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Lucky Food & Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.024793263386,
#  'FHRSID': 695287,
#  'LocalAuthorityBusinessID': 'PI/000182135',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SB',
#  'RatingDate': '2022-06-25T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d65b'),
#  'geocode': {'latitude': 51.4878934, 'longitude': 0.0910104},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695287',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '99 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Dilkush Tandoori',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4647.026394268489,
#  'FHRSID': 695400,
#  'LocalAuthorityBusinessID': 'PI/000184827',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SB',
#  'RatingDate': '2021-06-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d65c'),
#  'geocode': {'latitude': 51.4878941, 'longitude': 0.0909672},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695400',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '106 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': "Dadoo's Foodstore",
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.035076669946,
#  'FHRSID': 694604,
#  'LocalAuthorityBusinessID': 'PI/000116545',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2020-01-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d670'),
#  'geocode': {'latitude': 51.4876894, 'longitude': 0.0905233},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694604',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '104 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'High Street News & Wine',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.041728368117,
#  'FHRSID': 815071,
#  'LocalAuthorityBusinessID': 'PI/000198802',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SJ',
#  'RatingDate': '2021-01-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d678'),
#  'geocode': {'latitude': 51.4876718, 'longitude': 0.0903232},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/815071',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '104 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Everest Stores Ltd',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.041728368117,
#  'FHRSID': 695033,
#  'LocalAuthorityBusinessID': 'PI/000172986',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SJ',
#  'RatingDate': '2021-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d67a'),
#  'geocode': {'latitude': 51.4876718, 'longitude': 0.0903232},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695033',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '102 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Premier Express',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.038806595731,
#  'FHRSID': 695566,
#  'LocalAuthorityBusinessID': 'PI/000188497',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SJ',
#  'RatingDate': '2021-06-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d67b'),
#  'geocode': {'latitude': 51.4877234, 'longitude': 0.0904552},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695566',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': 'The Old Mill 1 Old Mill Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'The Old Mill',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4647.050320500107,
#  'FHRSID': 694555,
#  'LocalAuthorityBusinessID': 'PI/000111022',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QG',
#  'RatingDate': '2022-03-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d68e'),
#  'geocode': {'latitude': 51.4817109, 'longitude': 0.0840959},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694555',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '100 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'The Belfry',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4647.06014692546,
#  'FHRSID': 732579,
#  'LocalAuthorityBusinessID': 'PI/000116525',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SJ',
#  'RatingDate': '2021-08-28T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d6a4'),
#  'geocode': {'latitude': 51.487928, 'longitude': 0.0900757},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/732579',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '16 Warwick Terrace',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'The Plumstead Pantry',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.0653847124595,
#  'FHRSID': 1298993,
#  'LocalAuthorityBusinessID': '13950',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QJ',
#  'RatingDate': '2021-04-01T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d6a9'),
#  'geocode': {'latitude': 51.4817727, 'longitude': 0.083745},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1298993',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '98B Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Chick Chicken',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.077153359202,
#  'FHRSID': 694629,
#  'LocalAuthorityBusinessID': 'PI/000117347',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SL',
#  'RatingDate': '2020-07-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d6b6'),
#  'geocode': {'latitude': 51.4880687, 'longitude': 0.0897508},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694629',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Conway Primary School Gallosson Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Conway Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4647.079357879319,
#  'FHRSID': 694338,
#  'LocalAuthorityBusinessID': 'PI/000061059',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QY',
#  'RatingDate': '2022-06-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d6bf'),
#  'geocode': {'latitude': 51.487865447998, 'longitude': 0.0894860029220581},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694338',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '94 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Best Halal Meat Limited',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.085639006036,
#  'FHRSID': 1100050,
#  'LocalAuthorityBusinessID': '12389',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SL',
#  'RatingDate': '2021-11-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d6d1'),
#  'geocode': {'latitude': 51.4881611, 'longitude': 0.089611},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1100050',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '90 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Boba & Co UK',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4647.088848370269,
#  'FHRSID': 1382055,
#  'LocalAuthorityBusinessID': '14436',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SL',
#  'RatingDate': '2021-08-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d6ec'),
#  'geocode': {'latitude': 51.4881627, 'longitude': 0.0895246},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1382055',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '148 - 156 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Poundland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4647.104356784928,
#  'FHRSID': 1028778,
#  'LocalAuthorityBusinessID': 'PI/000204596',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2021-06-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d6fd'),
#  'geocode': {'latitude': 51.4884195010951, 'longitude': 0.0893575026992294},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1028778',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '204 Plumstead Common Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Spice Island',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.108530611648,
#  'FHRSID': 694596,
#  'LocalAuthorityBusinessID': 'PI/000116263',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 2RS',
#  'RatingDate': '2022-03-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d704'),
#  'geocode': {'latitude': 51.4804420471191, 'longitude': 0.0812250003218651},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694596',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': '59 Waverley Crescent',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'SD News & Mini Market',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.124518127556,
#  'FHRSID': 1063080,
#  'LocalAuthorityBusinessID': 'PI/000206865',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 7QU',
#  'RatingDate': '2021-06-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d713'),
#  'geocode': {'latitude': 51.4827461242676, 'longitude': 0.0831020027399063},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1063080',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '66 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'KFC',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.1284804779125,
#  'FHRSID': 1396464,
#  'LocalAuthorityBusinessID': '14614',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SL',
#  'RatingDate': '2021-08-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d71e'),
#  'geocode': {'latitude': 51.4884997, 'longitude': 0.0887766},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1396464',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '196 - 212 Plumstead Common Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Co-op Food',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4647.130907021743,
#  'FHRSID': 694595,
#  'LocalAuthorityBusinessID': 'PI/000116249',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2020-11-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d725'),
#  'geocode': {'latitude': 51.4806876203642, 'longitude': 0.0808583091748281},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694595',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '62A Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Ambala & Karahi Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.139639291201,
#  'FHRSID': 1096694,
#  'LocalAuthorityBusinessID': '12306',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SL',
#  'RatingDate': '2021-05-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d735'),
#  'geocode': {'latitude': 51.4885934, 'longitude': 0.0885648},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1096694',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'The Ship 205 Plumstead Common Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Los carnales mexicanos',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4647.169432009829,
#  'FHRSID': 1406601,
#  'LocalAuthorityBusinessID': '14699',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 2UJ',
#  'RatingDate': '2021-09-01T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d76e'),
#  'geocode': {'latitude': 51.4810979, 'longitude': 0.0802144},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1406601',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'East Plumstead Baptist Church Griffin Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'East Plumstead Pre School',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4647.170481326419,
#  'FHRSID': 695318,
#  'LocalAuthorityBusinessID': 'PI/000182731',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 7PZ',
#  'RatingDate': '2021-06-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d770'),
#  'geocode': {'latitude': 51.4845542907715, 'longitude': 0.0836590006947517},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695318',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Petrol Filling Station 160 - 168 Plumstead Common Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Plumstead Common Petrol Station',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.18661908045,
#  'FHRSID': 944957,
#  'LocalAuthorityBusinessID': 'PI/000183905',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 2UL',
#  'RatingDate': '2021-07-07T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d781'),
#  'geocode': {'latitude': 51.4806732, 'longitude': 0.0793165},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/944957',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '14 Conway Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Apna Grill',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.186753674302,
#  'FHRSID': 1226528,
#  'LocalAuthorityBusinessID': '13342',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1AH',
#  'RatingDate': '2020-08-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d782'),
#  'geocode': {'latitude': 51.4870876, 'longitude': 0.0857591},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1226528',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '191 Plumstead Common Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': "Flames Kebab Ltd trading as Morley's",
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4647.187942950943,
#  'FHRSID': 1152320,
#  'LocalAuthorityBusinessID': '12806',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 2UJ',
#  'RatingDate': '2022-01-12T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d783'),
#  'geocode': {'latitude': 51.4810714, 'longitude': 0.0796803},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1152320',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 0}}
# {'AddressLine1': '13 Conway Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Conway Road Supermarket',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.191819228341,
#  'FHRSID': 1031342,
#  'LocalAuthorityBusinessID': 'PI/000205344',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1AH',
#  'RatingDate': '2020-10-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d788'),
#  'geocode': {'latitude': 51.4873374, 'longitude': 0.0858713},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1031342',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '154 Plumstead Common Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'The Plum Tree Beer Shop',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4647.216229043659,
#  'FHRSID': 1451406,
#  'LocalAuthorityBusinessID': '14958',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 2UL',
#  'RatingDate': '2022-02-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d793'),
#  'geocode': {'latitude': 51.4808287, 'longitude': 0.078661},
# ...
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d8f1'),
#  'geocode': {'latitude': 51.4950485229492, 'longitude': 0.0835620015859604},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694900',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '95 Plumstead Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'GMT Kitchen and Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.56162094585,
#  'FHRSID': 947998,
#  'LocalAuthorityBusinessID': 'PI/000202511',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 7DQ',
#  'RatingDate': '2022-03-23T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d8f6'),
#  'geocode': {'latitude': 51.4903331, 'longitude': 0.0787421},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/947998',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '95 Plumstead Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'BR6',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4647.56162094585,
#  'FHRSID': 695385,
#  'LocalAuthorityBusinessID': 'PI/000184451',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 7DQ',
#  'RatingDate': '2020-09-28T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d8f8'),
#  'geocode': {'latitude': 51.4903331, 'longitude': 0.0787421},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695385',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '95 Plumstead Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Catering & Hospitality Education Dep',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4647.56162094585,
#  'FHRSID': 695707,
#  'LocalAuthorityBusinessID': 'PI/000192457',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 7DQ',
#  'RatingDate': '2020-10-20T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d90b'),
#  'geocode': {'latitude': 51.4903331, 'longitude': 0.0787421},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '190 Whinchat Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Thamesmead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'The Real Deal',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4647.629743175956,
#  'FHRSID': 1154241,
#  'LocalAuthorityBusinessID': '12817',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE28 0DR',
#  'RatingDate': '2020-07-30T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d94b'),
#  'geocode': {'latitude': 51.4978398, 'longitude': 0.0844204},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1154241',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Unit 14 I O Centre Seymour Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Borna',
#  'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  'ChangesByServerID': 0,
#  'Distance': 4647.66278774447,
#  'FHRSID': 1226526,
#  'LocalAuthorityBusinessID': '13338',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 6SX',
#  'RatingDate': '2020-09-22T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d97c'),
#  'geocode': {'latitude': 51.4918377, 'longitude': 0.0774802},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1226526',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '28 Allenby Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Thamesmead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Blossom Place Olive Services',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4647.674235398116,
#  'FHRSID': 694051,
#  'LocalAuthorityBusinessID': 'PI/000002353',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE28 0BN',
#  'RatingDate': '2021-04-21T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d988'),
#  'geocode': {'latitude': 51.4942476, 'longitude': 0.0795886},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694051',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Heronsgate Primary School Burrage Grove Campus Burrage Grove',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Heronsgate Primary School Royal Arsenal Campus',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4647.714088390572,
#  'FHRSID': 1385142,
#  'LocalAuthorityBusinessID': '14492',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 7LJ',
#  'RatingDate': '2021-10-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d9a7'),
#  'geocode': {'latitude': 51.4898490905762, 'longitude': 0.074074998497963},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1385142',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Menagerie Cafe Unit 9 The I O Centre Skeffington Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Menagerie Cafe',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4647.718461705105,
#  'FHRSID': 1112594,
#  'LocalAuthorityBusinessID': '12607',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 6SR',
#  'RatingDate': '2020-09-08T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d9ad'),
#  'geocode': {'latitude': 51.4914321899414, 'longitude': 0.075545996427536},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1112594',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Unit 38 The I O Centre Armstrong Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'PLOT Roasting',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4647.742227445188,
#  'FHRSID': 1156702,
#  'LocalAuthorityBusinessID': '12845',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 6RS',
#  'RatingDate': '2020-10-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d9bb'),
#  'geocode': {'latitude': 51.4935863, 'longitude': 0.0770593},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1156702',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': 'Unit 21 - 22 The I O Centre Armstrong Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Innova Nutraceutics Ltd',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.742227445188,
#  'FHRSID': 1468524,
#  'LocalAuthorityBusinessID': '15011',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 6RS',
#  'RatingDate': '2022-08-09T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d9bc'),
#  'geocode': {'latitude': 51.4935863, 'longitude': 0.0770593},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1468524',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '5 Gunnery Terrace Cornwallis Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Foodelo',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4647.790435013738,
#  'FHRSID': 1243199,
#  'LocalAuthorityBusinessID': '13395',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 6SW',
#  'RatingDate': '2021-02-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d9ec'),
#  'geocode': {'latitude': 51.4923133850098, 'longitude': 0.0744580030441284},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1243199',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Unit 6 9 - 11 Gunnery Terrace Cornwallis Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Woolwich',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Brighter Futures Project',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4647.804565120756,
#  'FHRSID': 1388277,
#  'LocalAuthorityBusinessID': '14533',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 6SW',
#  'RatingDate': '2021-08-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6783273b4905d7d92829d9fe'),
#  'geocode': {'latitude': 51.4922421, 'longitude': 0.0739989},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1388277',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert the results to a Pandas DataFrame to view more clearly
documents = list(establishments.find(query))
df = pd.DataFrame(documents)

# Extrating the values of Hygiene and putting it in a new column
df['Hygiene'] = df['scores'].apply(lambda x: x.get('Hygiene') if isinstance(x, dict) else None)

# Sorting out from lowest to highest Hygiene score
df_sorted = df.sort_values(by="Hygiene", ascending=True)


# Display the number of rows in the DataFrame
print("Number of nearby establishments:", len(df))

# Display the first 10 rows of the DataFrame
df_sorted.head(10)
# Out:
# Number of nearby establishments: 87
#                          _id   FHRSID  ChangesByServerID  \
# 43  6783273b4905d7d92829d7af   695460                  0
# 61  6783273b4905d7d92829d840  1319113                  0
# 60  6783273b4905d7d92829d83e   694127                  0
# 59  6783273b4905d7d92829d836  1489067                  0
# 58  6783273b4905d7d92829d834   694635                  0
# 57  6783273b4905d7d92829d829   695316                  0
# 53  6783273b4905d7d92829d7f1   695243                  0
# 52  6783273b4905d7d92829d7eb   841434                  0
# 48  6783273b4905d7d92829d7cb   695658                  0
# 47  6783273b4905d7d92829d7c3   695597                  0
#
#    LocalAuthorityBusinessID                      BusinessName  \
# 43             PI/000186310             Bear Hugs Day Nursery
# 61                    14007                  Suya Academy Ltd
# 60             PI/000020378                   D J Off Licence
# 59                    15088          Wilson & Bay Coffee Club
# 58             PI/000117510            Jhas Catering Services
# 57             PI/000182673                        McDonald's
# 53             PI/000179117                  Danfe Restaurant
# 52             PI/000195531  The Eggfree Cake Box (Plumstead)
# 48             PI/000191228      Peace Manor Residential Care
# 47             PI/000189492                        Kings Cafe
#
#                BusinessType  BusinessTypeID  \
# 43          Caring Premises               5
# 61  Restaurant/Cafe/Canteen               1
# 60        Retailers - other            4613
# 59   Takeaway/sandwich shop            7844
# 58  Other catering premises            7841
# 57  Restaurant/Cafe/Canteen               1
# 53  Restaurant/Cafe/Canteen               1
# 52        Retailers - other            4613
# 48          Caring Premises               5
# 47  Restaurant/Cafe/Canteen               1
#
#                                 AddressLine1 AddressLine2 AddressLine3  ...  \
# 43                         104 Waverley Road                 Plumstead  ...
# 61                        148 Plumstead Road                  Woolwich  ...
# 60                          13A Brewery Road                 Plumstead  ...
# 59  Plumstead Railway Station Walmer Terrace                 Plumstead  ...
# 58                        153 Plumstead Road                  Woolwich  ...
# 57                        3 Pettman Crescent                Thamesmead  ...
# 53                         89 Walmer Terrace                 Plumstead  ...
# 52                     Shop 18 Lakedale Road                 Plumstead  ...
# 48                          68 Waverley Road                 Plumstead  ...
# 47                  14 Plumstead High Street                 Plumstead  ...
#
#       LocalAuthorityEmailAddress  \
# 43  health@royalgreenwich.gov.uk
# 61  health@royalgreenwich.gov.uk
# 60  health@royalgreenwich.gov.uk
# 59  health@royalgreenwich.gov.uk
# 58  health@royalgreenwich.gov.uk
# 57  health@royalgreenwich.gov.uk
# 53  health@royalgreenwich.gov.uk
# 52  health@royalgreenwich.gov.uk
# 48  health@royalgreenwich.gov.uk
# 47  health@royalgreenwich.gov.uk
#
#                                                scores SchemeType  \
# 43  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 61  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 60  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 59  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 58  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 57  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 53  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 52  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 48  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 47  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                               geocode RightToReply  \
# 43   {'longitude': 0.0812914, 'latitude': 51.4838756}
# 61   {'longitude': 0.0839974, 'latitude': 51.4901495}
# 60   {'longitude': 0.0801741, 'latitude': 51.4862246}
# 59   {'longitude': 0.0839053, 'latitude': 51.4897501}
# 58   {'longitude': 0.0842824, 'latitude': 51.4900815}
# 57   {'longitude': 0.0853967, 'latitude': 51.4908567}
# 53   {'longitude': 0.0853618, 'latitude': 51.4893348}
# 52  {'longitude': 0.0857344851907352, 'latitude': ...
# 48    {'longitude': 0.0814574, 'latitude': 51.484673}
# 47   {'longitude': 0.0861158, 'latitude': 51.4892216}
#
#        Distance NewRatingPending  \
# 43  4647.231957            False
# 61  4647.363243            False
# 60  4647.358806            False
# 59  4647.351961            False
# 58  4647.350357            False
# 57  4647.338141            False
# 53  4647.283622            False
# 52  4647.281457            False
# 48  4647.255130            False
# 47  4647.251976            False
#
#                                                  meta  \
# 43  {'dataSource': None, 'extractDate': '0001-01-0...
# 61  {'dataSource': None, 'extractDate': '0001-01-0...
# 60  {'dataSource': None, 'extractDate': '0001-01-0...
# 59  {'dataSource': None, 'extractDate': '0001-01-0...
# 58  {'dataSource': None, 'extractDate': '0001-01-0...
# 57  {'dataSource': None, 'extractDate': '0001-01-0...
# 53  {'dataSource': None, 'extractDate': '0001-01-0...
# 52  {'dataSource': None, 'extractDate': '0001-01-0...
# 48  {'dataSource': None, 'extractDate': '0001-01-0...
# 47  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links Hygiene
# 43  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 61  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 60  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 59  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 58  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 57  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 53  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 52  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 48  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
# 47  [{'rel': 'self', 'href': 'http://api.ratings.f...       0
#
# [10 rows x 29 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

pipeline = [
    # 1. Match establishments with a hygiene score of 0
    {"$match": {"scores.Hygiene": 0}},
    
    # 2. Group by Local Authority
    {"$group": {
        "_id": "$LocalAuthorityName",  
        "count": {"$sum": 1},  # Count the number of establishments in each Local Authority
        "establishments": {"$push": "$BusinessName"}  # Collect the names of establishments
    }},
    
    # 3. Sort by count of establishments in descending order (highest to lowest)
    {"$sort": {"count": -1}}  # -1 for descending order
]
# Execute the aggregation pipeline
results = establishments.aggregate(pipeline)

# Print the number of documents in the result
result_list = list(results)  # Convert the aggregation cursor to a list
print(f"Number of Local Authorities with establishments having a hygiene score of 0: {len(result_list)}")

# Print the first 10 results
for result in result_list[:10]:
    pprint(result)
# Out:
# Number of Local Authorities with establishments having a hygiene score of 0: 55
# {'_id': 'Thanet',
#  'count': 1130,
#  'establishments': ['Tunnels Tea Shop',
#                     'Granville Theatre',
#                     'Toll Gate Kiosk',
#                     'Comfort Inn',
#                     'Whitecliff House',
#                     'Oak House',
#                     'Ramsgate Beach Kiosk',
#                     'Waterfront',
#                     'Sorbetto',
#                     'A La Turka',
#                     'Alexandra Restaurant',
#                     'The Little Vegan Food Place',
#                     'Food on Focus',
#                     'The Dog House & Grill',
#                     'The Nourish Bar',
#                     'Peters Fish Factory',
#                     'Royal Victoria Pavilion',
#                     'The Queens Head',
#                     'Perfecto Pasta and pizza',
#                     "Topp's Seafood",
#                     'Cannons of Ramsgate',
#                     'Thai Passion',
#                     'Alison Sea View Cafe',
#                     "Sam's Bar",
#                     'Royal Harbour Ramsgate Brasserie',
#                     'Enoteca',
#                     'The Oak Hotel',
#                     'Rokka',
#                     'The Glass House Tea Garden',
#                     'What Gwaan Limited',
#                     'Thanet Bowling Club',
#                     'Travellers in Italy',
#                     'Albion House Ramsgate',
#                     'Premier G & A Stores',
#                     'Dumpton Lodge',
#                     'Mother Goose Nursery',
#                     'Baker Street Cafe',
#                     'The Royal',
#                     'Gallegos Piri Piri',
#                     'Camden Arms',
#                     'D Suga Hut',
#                     'Clique Bar',
#                     'Little Ships',
#                     'Ramsgate Seafront Travelodge',
#                     'Coastal Bar Kent (Ltd)',
#                     'Crusties',
#                     'Buckmaster Home',
#                     "Gerry's Coffee & Art House",
#                     "Coco Latino & Clarey's Chocolates",
#                     'The Arch',
#                     'Ship Shape',
#                     'The Greek Arch',
#                     'Bodrum Kebab',
#                     'Archive Homestore',
#                     'Il Tricolore',
#                     'Ramsgate Tandoori',
#                     'Harbour Street Bar',
#                     'The Royal Fish Bar',
#                     'Taylor Meats Ltd',
#                     'The Goose',
#                     'Village Grill',
#                     'T.L.C',
#                     'RAFA Club',
#                     'Jah Jah',
#                     'Book Bodega',
#                     'Oban Supermarket',
#                     'Sunrise Cafe Restaurant',
#                     'Corbys Tearooms',
#                     'Wilkinson',
#                     'The Hovelling Boat Inn',
#                     'Mariners',
#                     'Keystore',
#                     'Crown',
#                     'The Home Front Tea Room',
#                     'Marc-Pierres Kitchen',
#                     'The Galley',
#                     'LA. Magnolia Ice Cream & Deli',
#                     'Thai Orchid',
#                     'La Magnolia',
#                     'Red Lion',
#                     'The York Arms',
#                     "Toni's Newsagents",
#                     'Papa George',
#                     'Curio Collectors Emporium',
#                     'Royal Temple Yacht Club',
#                     'Heaven and Hell Gifts',
#                     'Ramsgate Fish and Chips',
#                     'Victoria Off Licence',
#                     'Staple Stores',
#                     'Harbour Bakery',
#                     'Earl St Vincent',
#                     'Montefiore Arms',
#                     'Honeysuckle Inn',
#                     'Royal Harbour Hotel',
#                     'Hearth Restaurant',
#                     'The Lookout',
#                     'Sunrise Fish & Chips',
#                     'Zest Cafe & Bar',
#                     'KFC - Ramsgate',
#                     'Victoria Express',
#                     'Pizza 2 Night',
#                     'C and K Rileys Ltd',
#                     'Dirtee Feast',
#                     'Ravensgate Arms',
#                     'Costcutter',
#                     'BB Pasta & Pizza',
#                     'Moonshine Billys',
#                     'M & M Kebab Shop',
#                     'Good Fortune',
#                     'The Deal Cutter',
#                     'Souvlike - eat',
#                     'Iceland Foods Limited',
#                     'Subway',
#                     'Prentis',
#                     'Star Nergis',
#                     "Seaside's Restaurant",
#                     'Churchill Tavern',
#                     'Phoenix Care Homes Ltd',
#                     'Poundland',
#                     'Boots UK Ltd',
#                     'Holland & Barrett',
#                     'The Royal British Legion',
#                     'Bromley Lodge',
#                     'Ho Wong',
#                     'Union Ramsgate',
#                     'The Sun Club',
#                     'Elephant and Castle',
#                     'Harvest Health Foods',
#                     'The Corner Broadstairs',
#                     'Spice Garden',
#                     'Friends Fish and Chips',
#                     'Louisa Bay Cafe',
#                     'Sage Cafe Ramsgate',
#                     'Tesco',
#                     'Hereson News',
#                     'Star of China',
#                     'Coffee Hut',
#                     'Grub Hub',
#                     'Holy Trinity CEP School',
#                     'Viking',
#                     'W H Smith',
#                     'Kids Brighthouse',
#                     'R S Off Licence & Newsagents',
#                     'Ramsgate Masonic Centre',
#                     'The Falstaff',
#                     'Waitrose Ltd',
#                     'Queen Charlotte',
#                     "Dee's Cafe",
#                     'Broadstairs Sailing Club',
#                     'Tartar Frigate',
#                     'Main Refreshment Kiosk',
#                     'Wyatt and Jones',
#                     'The Pavilion',
#                     'Jetty Broadstairs',
#                     'Panorama Restaurant',
#                     "Queen's Kebab",
#                     'Former Aldi Store',
#                     'Bradstowe Lodge',
#                     'Cintra Hotel',
#                     'Cleveland House Ltd',
#                     'The Funicular Coffeehouse',
#                     'Golden Fish Bar',
#                     'Subway',
#                     'York Gate Ices',
#                     'Spencer Court Hotel',
#                     'Londis',
#                     'Lillyputt Mini Golf',
#                     'Bradstow School',
#                     'Addington Superstore',
#                     'Flavours By Kumar',
#                     'United Church',
#                     'The Modern Boulangerie',
#                     'The Charles Dickens',
#                     'Moffetts Kiosk',
#                     'Kebbells',
#                     'Clarendon & Chatham House Sixth Form Centre',
#                     'Chiappinis Coffee Shop',
#                     'Bandstand Kiosk',
#                     'Cafe Loki',
#                     'Neptunes Hall',
#                     'Harpers Wine Bar',
#                     'The Old Curiosity Shop',
#                     'Artfuls',
#                     'West Cliff Service Station',
#                     'International Food Store',
#                     'Happily Ever Afters',
#                     'Royal Albion Hotel',
#                     "Eats 'n' Beats",
#                     'Ethelbert Childrens Services',
#                     'The Hive Cafe',
#                     'St Ethelberts Roman Catholic Primary School',
#                     'Costa Coffee',
#                     "St George's Community Meal",
#                     'DOS',
#                     'The Table',
#                     'St Ethelberts Breakfast Club',
#                     'Stone Bay Montessori & Beach School',
#                     'La Zia Maria',
#                     'New China Inn',
#                     'Be Me Tea Limited',
#                     "Veg'N Out",
#                     'Siam Kitchen',
#                     'The George Inn',
#                     'The Mermaid Fish & Chips Restaurant',
#                     'Aqua 43',
#                     'Beaches Cafe Bar',
#                     "Seggari's",
#                     'Seafarer Restaurant',
#                     'The Chapel',
#                     "Bessie's Tea Parlour",
#                     'The Dolphin Lounge Bar',
#                     'Osteria Posillipo',
#                     'Clarendon House Grammar School',
#                     'Sardinia',
#                     'Samworth & Mee',
#                     "Raindell's",
#                     'The Sea Lounge',
#                     'Smokehouse',
#                     'Prezzo',
#                     'Albarino Tapas Restaurant Bar',
#                     'The Racing Greyhound',
#                     'The Pickled Herring',
#                     'Macies Bar',
#                     'The Dining Room',
#                     'The Gardners Retreat Restaurant',
#                     'Reign Bar & Lounge',
#                     'Wrotham Arms',
#                     'Tesco',
#                     'Bedford Inn',
#                     'Thanet Childcare Ltd',
#                     'Smiths Coffee Bar',
#                     'Rueanthai Shop',
#                     'The Little Sicilian',
#                     'Thai Four Two',
#                     'Helter Skelter Nursery',
#                     'Kyoto Sushi & Grill',
#                     'Golden Fortune',
#                     'Rooms at Number One',
#                     'Ramsgate Small Boat Owners Assoc',
#                     'Royal Naval Association',
#                     'Premier',
#                     "Sancho's",
#                     'Best Fish & Chips',
#                     'Please Sir',
#                     'The Prince Albert',
#                     'Pork & Co Limited',
#                     'Star of the Sea',
#                     'The Crown',
#                     'The Old Bakehouse',
#                     "Ed's Cafe",
#                     'Iceland Foods Limited',
#                     'Londis',
#                     'J Prentis Fruiterers & Greengrocers',
#                     'Premier',
#                     'Belvidere Place',
#                     'Rose of England',
#                     'Queens Road Baptist Church',
#                     'Victory News',
#                     'Beano Cafe',
#                     'Copperfields B & B',
#                     'Broadstairs House',
#                     'The Counting House',
#                     'East Kent College',
#                     'Crusties Bakery',
#                     'Chatham House & Clarendon House',
#                     'CCCP Restaurant',
#                     'Oriental Chef',
#                     'Montessori Nursery',
#                     'The Devonhurst',
#                     'Papa Johns',
#                     'The Kent School of English',
#                     'St Lukes Stores',
#                     'Fish Inn Ltd',
#                     'Ramsgate Care Centre',
#                     'Pop-In',
#                     'Brenan House',
#                     'The Ramsgate Balti Takeaway',
#                     'Spice Fusion',
#                     'Mayflower Take-away',
#                     'The Townley',
#                     'Explorers',
#                     'The Curry House',
#                     'Priory County Infants Breakfast Club',
#                     'Priory County Infant School',
#                     'Golden Fortune',
#                     "Sinatra's",
#                     'Crescent Stores',
#                     'East Kent Arms',
#                     'Co - Op Welcome',
#                     'Play Wise',
#                     'St Lukes Parish Hall',
#                     'Dumpton Post Office',
#                     'Ramsgate Sports Centre',
#                     'The Odds',
#                     'Asda Stores Limited',
#                     'The Salvation Army',
#                     'The Boating Pool',
#                     'Ramsgate Croquet Club',
#                     'The Boating Pool',
#                     'Mr lemonheads',
#                     'Christ Church Junior School',
#                     'Creta',
#                     'Kope & Loko',
#                     "Houdini's Magic Bar Ltd",
#                     'Co-operative Food',
#                     'Cafe Grill',
#                     'Roostys Bakery',
#                     'Broadstairs & St Peters Bowling Club',
#                     'South Eastern Tavern',
#                     'Hotel De Ville',
#                     'Conqueror Alehouse',
#                     'China City',
#                     'Cardak Meze & Grill',
#                     'Chef & Butcher',
#                     'Keele House',
#                     'Pizza Hut',
#                     'Broadstairs Kebab',
#                     'Vale Tavern',
#                     'Bradstow Mill',
#                     'Mind The Gap',
#                     'Stone Bay School',
#                     'Aysan Kebab Pizza',
#                     'Londis',
#                     'Langmead Guest House',
#                     'Thanet Early Years Project',
#                     'Beano Cafe',
#                     'Green Coffee House and Wine Bar',
#                     'Newlands County Primary School',
#                     'Newlands CP School Breakfast Club',
#                     'Broadstairs Cricket Club',
#                     'Lucky House',
#                     'St Mildreds County Primary School',
#                     'Salt of the Earth',
#                     'STB Pizza',
#                     'Premier',
#                     "Daa's Thai Diner",
#                     'Station Fish Bar & Grill',
#                     'Lawns',
#                     'Ramsgate Kebab',
#                     'Thanet Squash Rackets Club',
#                     'The Pines',
#                     'Wantsum Lodge',
#                     'Ashdene',
#                     'St Lawrence College',
#                     'Fruits De Mer',
#                     'Wellesley House School',
#                     'Winon',
#                     'Naughty But Nice',
#                     'The Beano Cafe',
#                     'Best One Express',
#                     'Dream Kitchen Kebab House',
#                     'Rent A Bar Units 123',
#                     'Haddon Dene School',
#                     'The Royston Micropub',
#                     'Broadstairs English Centre',
#                     'Broadstairs & St Peters Comrades Clu',
#                     'St Lawrence Bowls Club',
#                     'West Dumpton Stores',
#                     'Dou Dou Chinese',
#                     'Viaduct Stores',
#                     'Upton Junior School',
#                     'Budgens Local',
#                     'The Ramsgate Club',
#                     'The Square Dozen',
#                     'Yummy Chinese Takeaway',
#                     'Thanet Winter Shelter',
#                     'The Flying Horse',
#                     'ChristChurch School Breakfast Club',
#                     'Pie Factory',
#                     'Australian Arms',
#                     'Fledglings Nursery School',
#                     'Breakfast & After School Club',
#                     'St Josephs School',
#                     'The Albion Inn',
#                     'The Sir Stanley Gray',
#                     'Belle Vue Tavern',
#                     'Pumpkin',
#                     'Foliage plants',
#                     'Delicious Fish Bar',
#                     'St Lawrence Local',
#                     'St Lawrence Tandoori',
#                     'Sexy Burger',
#                     'Tesco',
#                     "Domino's Pizza",
#                     'Bargain Booze',
#                     'The Four Candles Alehouse',
#                     'St Lawrence Tavern',
#                     'Tycoon',
#                     'Thanet Kebab & Pizza',
#                     'St Laurence In Thanet Junior Academy',
#                     'The Lanthorne',
#                     'St Laurence Breakfast Club',
#                     'New Jumbo Chinese Takeaway',
#                     'The Pavilion Cafe',
#                     'Wychdene',
#                     'The Learning Tree',
#                     'Chilton County Primary School',
#                     'Royal Harbour Academy',
#                     'Foreland Fields School',
#                     'Thanet Wanderers',
#                     'Red Arrows Club',
#                     'Joss Bay Cafe',
#                     'Barbies Playschool And Selwyn House Nursery',
#                     'Royal British Legion',
#                     'Charles Dickens School',
#                     'Tiny Treasures Day Nursery',
#                     'Bromstone County Primary School',
#                     'Rydal Mini Mart',
#                     'North Star Off Licence',
#                     'Kent Residential Care Home',
#                     'Housing 21',
#                     'The Corner Coffee House',
#                     'Buttons Pre-School (Fegans)',
#                     'Port Regis Montessori Nursery',
#                     'Crusties',
#                     'Dane Court Grammar School',
#                     'Under 1 Roof Kids Thanet',
#                     'Stewarts Cafe',
#                     'The Windmill Pub',
#                     'Port Regis Nursing Home',
#                     'Blue Apple Contract Catering',
#                     'Newington Fish Bar',
#                     'Extended Day/Breakfast Club',
#                     'St Peter In Thanet Junior School',
#                     'Staple',
#                     'The White Swan',
#                     'Golf Club Restaurant',
#                     'Halfway House Cafe',
#                     'Ramsgate Brewery Ltd',
#                     'May King',
#                     'Best Moon Shop',
#                     'McColls',
#                     'Wholefood Earth',
#                     'Village Newsagents',
#                     'Callis Grange Breakfast Club',
#                     'Rams News',
#                     'Callis Grange County Primary School',
#                     'Newlyn House Residential Home',
#                     'Yard of Ale',
#                     'The Red Lion',
#                     'St Peters Stores',
#                     'Hogman Family Butchers',
#                     'Milk & More',
#                     'Pizza Go Go',
#                     'Pizza Place',
#                     'Pizza Alforno',
#                     'Ramsgate Arts School',
#                     'De Flame',
#                     'Morliss Fast Food',
#                     'St Peters Fish Bar',
#                     'Asda Stores Limited',
#                     'New Asia',
#                     'Peninsula',
#                     'Customer Restaurant',
#                     'Panku Broadstairs',
#                     'Shell Royal Oak',
#                     'Sense',
#                     'Newington Community Primary School',
#                     'Newington Community Centre',
#                     'Tandoori Express',
#                     'Lunch Club',
#                     'Co Operative Pioneer Store',
#                     'Sexy Burger',
#                     'Copperfields',
#                     'Peckish',
#                     'McDonalds Restaurants Ltd',
#                     'Scott-Dogs Mobile',
#                     'Dame Janet Breakfast Club',
#                     'Dame Janet Primary Academy Upper School',
#                     "Shorty's Nursery",
#                     'Botany Bay Beach Kiosk',
#                     'Northwood Club',
#                     'Hare & Hounds',
#                     'Mr Chips',
#                     'Elizabeth Pizza',
#                     'Best One',
#                     'Chun Chun',
#                     'Sycamore Stores',
#                     'Cabin Cafe',
#                     'The Cafe',
#                     'Tesco Ramsgate Manston',
#                     'Fosters',
#                     'Spar',
#                     'The Hook Up - Jayar',
#                     'Botany Bay Hotel',
#                     'Kingsgate Newsagents',
#                     'St Georges Secondary School',
#                     'Fairport Care Services',
#                     'The 19th Hole',
#                     'Barbies Footsteps',
#                     'The Stylish Ice Cream Co',
#                     'The Range',
#                     'Revolution Skate Park',
#                     "Dee Dee's Cafe",
#                     'Lidl',
#                     'The Sticky Wickett Sports Bar',
#                     'The Royal Harbour Acadamy',
#                     'The Shop on The Hill',
#                     'The Drinkshop.com Ltd',
#                     'Urban Grillaz',
#                     'Wholefood Earth Ltd',
#                     'Bannatynes Health Club',
#                     'SS Machinery UK',
#                     'Pegwell Bay Service Station',
#                     'Harris & Hoole Cafe',
#                     'The Cafe',
#                     'Tesco Extra',
#                     'The Gents Lodge',
#                     'Laleham Gap School',
#                     "Taddy's Barn Tea Room",
#                     'St Phillips Church',
#                     'Fairways Kitchen',
#                     'Priory Group Ltd',
#                     'The Martins',
#                     'Ebbsfleet Golf Centre',
#                     'Sainsburys',
#                     'The Canterbury Bell',
#                     'The Laughing Barrel',
#                     'McDonalds',
#                     'Lotus Garden',
#                     'Co-operative',
#                     'Palm Bay Fish Bar',
#                     'Premier Convenience Store',
#                     'Costa Coffee Drive Thru',
#                     'The Tenth',
#                     'Iceland Food Warehouse',
#                     'Poundstretcher',
#                     'B & M Stores',
#                     'Pizza Hut Restaurant',
#                     'Poundland',
#                     'Shop',
#                     'Dunelm Mill',
#                     'Wilkinsons',
#                     'Ask',
#                     'Thai Village Restaurant & Bar',
#                     'Grosvenor Casino',
#                     'Coffee Corner',
#                     'Vue Cinema',
#                     'Travelodge',
#                     'Mecca Bingo',
#                     'Boots UK Ltd',
#                     'Marks & Spencer Plc',
#                     'Costa Coffee',
#                     "Frankie & Benny's",
#                     'Subway',
#                     "Nando's",
#                     'Greggs',
#                     'Cafe Nero',
#                     'WH Smith',
#                     'Bella Italia',
#                     'CUP (Mobile)',
#                     'The Garden Gate Cafe',
#                     'All sorts of sweets and treats',
#                     'Kaspars',
#                     'Big Dees Fried Chicken',
#                     'Sunshine Pre-School',
#                     'Holy Trinity Cafe & Church Hall',
#                     'Cowley Rise Store',
#                     'Toby Carvery Thanet',
#                     'Hooden Horse',
#                     'Smokey Banditos',
#                     'Madison House',
#                     'Mulberry Court',
#                     'Farm Foods Ltd',
#                     'The Wheatsheaf',
#                     'Star Lane Stores',
#                     'Burger King Uk Ltd',
#                     'St Augustines Golf Club',
#                     'The Chai Stop',
#                     'Great Oaks Small School',
#                     'Meadows Nursery & Riverbank Club',
#                     'Millmead Early Years Centre',
#                     'Palm Bay Primary',
#                     'Northdown CP School Main Kitchen',
#                     'Just The Ticket Cafe',
#                     'The Crafty Little Cakery',
#                     'Jolly Farmer',
#                     'St Anthonys School',
#                     "The Avenues's  Montessori Nursery",
#                     'Home Bargains',
#                     'Holly Lane Fish Inn',
#                     'Cliftonville County Primary School',
#                     'The Village Pantry',
#                     'Premier',
#                     'Holly Lane Post Office & Stores',
#                     "Chicken Stop/Fat Daddy's",
#                     'The Lounge',
#                     'Global Generation Church',
#                     'Family Choice Mini Market',
#                     'Dane Valley Fish Bar',
#                     'Windmill Community Allotment Project',
#                     'Madre',
#                     'Bradgate Social Club',
#                     'Shell Margate Service Station',
#                     'Brothers Pizzeria',
#                     'TNS',
#                     'Tesco',
#                     'Yoakley House',
#                     "Aunty T's Kitchen",
#                     'Palm Bay Cafe',
#                     'Claremont Care Home',
#                     'Nazar Fish Bar',
#                     'Treetops Residential Home',
#                     'Redcot Lodge',
#                     'The Avenues Trust',
#                     'Tiarrah Pizza Bar',
#                     'Sense',
#                     "Gloria's Lounge & Cafe",
#                     'Pagoda Chinese T/A',
#                     'Northdown Pharmacy',
#                     'MFC',
#                     "Let's Go Pizza",
#                     'Jet Ski World Cafe',
#                     'Drapers Mill County Primary School',
#                     'Drapers Mill Breakfast Club',
#                     'TNS Local',
#                     'Maltreath',
#                     "Vera's",
#                     'Warwick Guesthouse',
#                     "Eddy's Fried Chicken Kebab",
#                     'Vinnys Cafe',
#                     'Skinny Dip Coffee',
#                     'Urchin Wines',
#                     'Approach Road Mini Mart',
#                     'International Food Centre',
#                     'The Oval Bandstand And Lawns',
#                     'Thanet Indoor Bowls Centre',
#                     'Graywood Care Home',
#                     'Green Gables',
#                     'R & Z Limited',
#                     'Batchelors Patisserie',
#                     'R & Z Ltd Cafe',
#                     'Aroma Cafe',
#                     'Cafe Kussan',
#                     'Walpole Bay Hotel',
#                     'Moylers',
#                     'The Tap Room',
#                     'The Bangkok Thai',
#                     'Costa Coffee',
#                     'Little Oaks Nursery',
#                     'QEQM Catering',
#                     'Stingray Drinks',
#                     'The Spencer Private Hospital',
#                     'Gresham Residential Home',
#                     "Ouma's Kitchen",
#                     'Aquarius Lodge',
#                     'Summerville Residential Home',
#                     'Pilgrims Hospice',
#                     'Cafe Continental',
#                     'ISS Mediclean Ltd',
#                     'Kent & Med NHS & Social Care P Trust',
#                     'TR Convenience Store',
#                     'The Belle Vue Tavern',
#                     "Kawa's Desserts",
#                     'Clifton Superstore - Premier',
#                     'Northdown Road Snooker Club',
#                     'Kebabish',
#                     'The Grain Grocer',
#                     'Lesters Pub & Restaurant',
#                     'Churchill Contract Catering, RADISH',
#                     'Cliftonville Outdoor Bowls Club',
#                     'Express Kebab',
#                     'International Mini Market',
#                     'Tom Thumb Theatre',
#                     'The Willows Care Centre',
#                     'Grosvenor Court Care Limited',
#                     'North Lodge',
#                     'Smiths Court Hotel Ltd',
#                     'Lick & Chew Sweet Supplies',
#                     'The Albion Rooms',
#                     'Rosslyn Court',
#                     'DWG Meat & Pies',
#                     'Days Supermarket',
#                     'Thanet Quality Foods',
#                     'The Lord Byron',
#                     'Tasty Kebab',
#                     'One Stop Stores',
#                     'Pasha',
#                     'TBS Pop UP',
#                     'Brightstart Nursery',
#                     'Cliffs',
#                     'EHIS Groceries',
#                     'Secret Spices',
#                     '101 Social Club',
#                     'Happy Cafe & Family Restaurant',
#                     "Henri's Pizzeria",
#                     'Fireaway Margate',
#                     "Andrew & Jill's General Store",
#                     'Baba Kebab House',
#                     'Premier Express Mini Mart',
#                     'Alfies Fish Bar',
#                     'Bayleaf Indian Curry House',
#                     'Ashcroft House',
#                     'St Gregorys Catholic Primary School',
#                     'St Gregorys Breakfast Club',
#                     'My Nursery',
#                     'The Oxford',
#                     'Salmestone County Primary School',
#                     'First Steps Nursery',
#                     'Yummy Thai',
#                     'Thanet Society of Druids Social Club',
#                     'New Life Family Church',
#                     'St Peters Home',
#                     'Dalby Cafe',
#                     'The Mulberry Tree',
#                     'Eata Pizza',
#                     'Bowling Club',
#                     'Dane Park Kiosk',
#                     'Al Madinah Foods',
#                     'Kebab House',
#                     'Resul Retail Ltd',
#                     'The Cliff',
#                     'Townsend Montessori Margate',
#                     "St Peter's Sausages",
#                     'Margate Leisure Centre',
#                     'Kitchen Social & Cookery Club cic',
#                     'Olympia Cafe',
#                     "Bugsy's Bowling Centre",
#                     'Mont Calm',
#                     'Faith in Strangers',
#                     'Mar Mar',
#                     'St Johns Community Centre',
#                     'Londis',
#                     'Thanet Express',
#                     'The Riz Convenience Store',
#                     'Shottendane Nursing Home',
#                     'We Are Here',
#                     'K G Winters',
#                     'The Master Cook',
#                     'Margate Indian Spice',
#                     'Sherwood Hotel',
#                     'Homewok Chinese Takeaway',
#                     'Quart in a Pint Pot',
#                     'Tivoli Cafe',
#                     'Riz Restaurant',
#                     'The Princess of Wales',
#                     'Costcutter',
#                     'Holy Trinity And St Johns C Of E Primary School',
#                     'Lawrence Stores',
#                     'Ty - 8',
#                     'Margate Family Shopper',
#                     'The Best Beano Cafe & Restaurant',
#                     'Six Bells Children Centre',
#                     'Poundstretcher Warehouse',
#                     'The London Tavern',
#                     'Theatre Royal',
#                     'The Cliff Bar',
#                     'Thanet Tasty Chicken',
#                     'Haeckels',
#                     'Forts Cafe',
#                     'Daisy',
#                     'The Reading Rooms',
#                     'Bar Nothing',
#                     'English in Margate',
#                     'The Salvation Army',
#                     'Cliftonville Off Licence',
#                     'Age UK  Thanet Ltd',
#                     'Kent Catering Company',
#                     'Mia Papas Kitchen',
#                     'Cambridge Villa Supported Living',
#                     'Super Pizza',
#                     'The Punch and Foody',
#                     'The Margate Caves Cafe',
#                     'Storeroom',
#                     'George Burgers',
#                     'McDonalds',
#                     'Sheldons',
#                     'Key Store Off Licence',
#                     "Gadd's Food & Drink",
#                     'Costcutter',
#                     "Widget's Toys",
#                     'Rose in June',
#                     'Milk and Cookie',
#                     'Winter Gardens',
#                     'Bay Guest House',
#                     'Curve Coffee Store',
#                     'The Pie Shop',
#                     'Infinity Coffee House',
#                     'Iceland Foods Limited',
#                     'Burger Bar',
#                     'Victoria Hotel Ltd',
#                     'The Hartsdown',
#                     'The George & Heart',
#                     'Palms Pizza',
#                     'C & S News',
#                     'Costa Coffee',
#                     'Kellys Sweets & Treats',
#                     'Greggs',
#                     'Elsewhere',
#                     'Poundland',
#                     'Modern Provider',
#                     'The New Odds Club',
#                     'Subway',
#                     'Seaside Cake Parlour',
#                     'Scissortail Ltd',
#                     'Edessa',
#                     'Margate Lawn Tennis Club',
#                     'Kawa',
#                     'The Little Fish Cafe',
#                     'Terrance House',
#                     'South Garden',
#                     'Tops Pizza',
#                     'Carbeez Jerk Chicken Takeaway',
#                     "Franklin's",
#                     'Giorgios',
#                     'Love Cafe',
#                     'Margate Masonic Lodge',
#                     'Cafe Darcy',
#                     'Silver Slipper Performing Arts Schoo',
#                     'Wig and Pen',
#                     "Bow's Kitchen",
#                     'Mullins Brasserie',
#                     "Ralph's",
#                     'The Britannia',
#                     'New Street Bistro',
#                     'Mama Jinny Thai Kitchen',
#                     'Beano Cafe & Family Restaurant',
#                     'Cafe de China',
#                     'Clock Tower Kebabs',
#                     'Our Kitchen',
#                     "L'Olivo",
#                     'Papa Johns',
#                     'Hantverk & Found',
#                     'The Clockwork Cocktail Company Ltd',
#                     'KFC - Margate',
#                     'Sundowners',
#                     'Kookidoe',
#                     "Olby's Soul Cafe",
#                     'Margate Express',
#                     'Zen by the Sea',
#                     'The Margate Bookshop',
#                     'Ramsay & Williams Ice Cream Bar',
#                     'The Lifeboat Ale and Cider House',
#                     'The Bulls Head',
#                     'Wildes',
#                     'The Greedy Cow',
#                     'Bottega Caruso, The Crown Gallery',
#                     'Masala Gate',
#                     'Beach Treats',
#                     'Alexandria Cafe',
#                     'Life is a Beach',
#                     'Waverley House',
#                     'Barnacles',
#                     'The Greek Kitchen',
#                     'Brens Diner & Bus',
#                     'Uncle Yupy',
#                     "Master Foody Moody's",
#                     "Gina's Old Bakery",
#                     'Jaffna South Indian',
#                     'Pan Asian Cuisine',
#                     'Breens Sweets',
#                     "Mae's Bar",
#                     'Mamma Mia Pizzeria',
#                     'MICommunity Shop',
#                     'Mannings Seafood',
#                     'The Little Prince',
#                     'Thao Thao Kitchen',
#                     'Lulus Gelato limited',
#                     'Khmer Kitchen @',
#                     'Harbour Cafe Bar',
#                     'Peters Fish Factory',
#                     'The Med',
#                     'The Margate Coffee Shed',
#                     'The Ocean Lounge',
#                     'SLAB',
#                     "Charlie's",
#                     'Cafe G',
#                     'J D Convenience Store',
#                     'Beet Bar',
#                     'Sands Hotel Margate Ltd',
#                     "Angela's of Margate",
#                     'Bowl Island ltd',
#                     'Big Shot',
#                     'The Glass Jar',
#                     'Fez',
#                     "Domino's Pizza",
#                     'Buoy and Oyster',
#                     'Little Swift',
#                     'Wetherspoons',
#                     'The Two Halves Margate',
#                     'Fond Coffee',
#                     'O Vesu Limited',
#                     'Oceans',
#                     'Rad Burger',
#                     'The Sweet Factory',
#                     'Cinque Ports',
#                     'Sands Restaurant & Cafe Bar',
#                     'Sunset Rock Shop',
#                     'The Candy Stop',
#                     'Kids Mayhem Clubworld',
#                     "Dory's",
#                     'Marine Express - Londis',
#                     'Pamela at The Turner Contemporary',
#                     'Imperial Lounge',
#                     'Great British Pizza Company Ltd',
#                     'Looking Ahead - Tea Rooms',
#                     'Hartsdown Academy',
#                     'Barletta',
#                     '13 Fitness',
#                     'Manor House Nursery School',
#                     'Atlantis Fish & Chips',
#                     'Guest House',
#                     'Hartsdown Leisure Centre',
#                     'Sea Shed',
#                     'Minster Village Hall',
#                     'Nelson Park Riding Centre',
#                     'Dive',
#                     'The Sargasso',
#                     'The Lighthouse Bar',
#                     'The Harbour Arms',
#                     'Brewers Fayre',
#                     'Coffee Station',
#                     'McDonalds Restaurant And Drive Through',
#                     'The Bell Inn',
#                     'Grub Hub',
#                     'Buy Whole Foods on Line',
#                     'The Pink House',
#                     'Pan Asian Cuisine',
#                     'Llee House',
#                     'Bright Star Nursery',
#                     'Sure Start',
#                     'The Bus Cafe',
#                     'Pork And Company Limited',
#                     'Staple',
#                     'Somerville Hotel',
#                     'Garlinge Primary School And Nursery',
#                     'Garlinge Junior Breakfast Club',
#                     'Garage Coffee',
#                     'The Kent Larder',
#                     'Nayland Rock Hotel',
#                     'Yummy Yummy',
#                     'Charcoal Grill',
#                     'Ali Raj',
#                     'Pizza 2Night',
#                     'Liquor Locker',
#                     "Archie's Fish and Chips",
#                     'Hair Of The Dog',
#                     'Casa Pizzeria & Cafe',
#                     'Westbrook Food and Wine',
#                     'Ales Of The Unexpected',
#                     'Westbrook Cafe',
#                     'Westbrook Convenience Store',
#                     'Minster Day Nursery',
#                     'Minster Primary School',
#                     'Kent Fresh',
#                     'Drink Margate',
#                     'Minster Kebabs',
#                     "Jemima's Tea Room",
#                     'China Chef',
#                     'The Salvation Army',
#                     'Kentish Sandwich Company',
#                     'The New Inn',
#                     'Westbrook Fish Bar',
#                     'Fifty 2',
#                     'Strokes Adventure Golf',
#                     'Tesco',
#                     'Costa Coffee Drive Thru',
#                     'Westbrook Club',
#                     'Amadeus Trattoria',
#                     'Garlinge Fish Bar',
#                     'Merlin Cafe',
#                     'Express By Holiday Inn',
#                     'Co Op Minster',
#                     'Westbrook Lodge Guest House',
#                     'Ivanhoe Avenues Group',
#                     'Garlinge Newsagents',
#                     'Smugglers Retreat Table Table',
#                     'Shaw Healthcare (FM Services)',
#                     'Royal British Legion Club',
#                     'Type One Style',
#                     "Barbara's Baps",
#                     "Mia's Cuisine",
#                     'Costcutter',
#                     'Flavours by Kumar',
#                     'Ibiza Fitness Food',
#                     'Rosedene Residential Home',
#                     'Marks & Spencer',
#                     'SPRY Craft Shots Ltd',
#                     'Sams Room Service',
#                     'Panda Chinese Take Away',
#                     'Blue Oceans',
#                     'The Hussar',
#                     'Birchington Vale',
#                     'Woodies Shop and Cafe',
#                     'The Westgate Care Centre',
#                     'Mermikides Community Centre',
#                     "Community Under 5's",
#                     'Westgate Community Centre',
#                     'Nourish Contract Catering Ltd',
#                     'St Crispins Breakfast Club',
#                     'Gordon Lodge',
#                     'Roxburgh House',
#                     'Avondale',
#                     "Millie's Beach Bar",
#                     "The St Mildred's Bay",
#                     'Little Brown Fairy Cake',
#                     'Windsor House',
#                     'Beano Cafe',
#                     'Beano Kebab',
#                     'Hot Wood Pizza',
#                     'J Prentis Greengrocers',
#                     'Co-op - Westgate',
#                     'Regency Tandoori',
#                     'The Best Beano Cafe',
#                     'St Augustines',
#                     'Lochaber Lodge',
#                     'The Maples',
#                     'Westgate on Sea Social Club',
#                     'Pats Pastys',
#                     'Cheeky Monkeys Preschool',
#                     "Ginger's",
#                     'Station Superstore',
#                     "Paul's Bar & Bistro",
#                     'The Corkscrew Off Licence',
#                     'Piggybank Day Nursery',
#                     'Krusty Kobb',
#                     'Quince',
#                     'Windsor House',
#                     'Staple Stores',
#                     'The Lodge',
#                     'Christchurch Lunch Club',
#                     'Eaton Lodge',
#                     'Best One',
#                     'The Chilterns',
#                     'Dadds Butchers',
#                     'Julias',
#                     'Westgate Town Council',
#                     'St Saviours School',
#                     'Food of love Thanet',
#                     'Carlton Cinema',
#                     'Golden Palace',
#                     'Westgate United Services Club',
#                     'Bake & Alehouse',
#                     'Fredericks Cafe',
#                     'Bethanys',
#                     'The Fish Inn',
#                     'New Friendly House',
#                     'Premier',
#                     'St Saviours Breakfast Club',
#                     'Ocean Swell Residential Home',
#                     "D'arcys Catering Limited",
#                     'St Michaels Nursing Home',
#                     'Bar Only',
#                     'Off the hook pizza',
#                     'Ursuline College',
#                     'Project 43',
#                     'Weddings & Events & Felicitys Cafe',
#                     'Quex Adventure Golf',
#                     'The Pearl Kitchen',
#                     'The White Stag',
#                     'Le Club the Foxhunter Park',
#                     'The King Ethelbert School',
#                     'The Swan by the Sea',
#                     'Quex Activity Centre',
#                     'Monkton County Primary School',
#                     'Quex Barn',
#                     'Quex Barn Pizza',
#                     "Monkton Under 5's Play group",
#                     'Finbars Restaurant',
#                     'West Bay Cafe',
#                     'The Cabin Eatery',
#                     'Principals',
#                     'Birchington CE Breakfast Club',
#                     'Noahs Ark Nursery',
#                     'Smugglers Restaurant',
#                     'Village Square Cafe',
#                     'Strawberry Fields',
#                     'The Cow Shed Bar & Grill',
#                     'New Dragon',
#                     'Martin McColls',
#                     'Birchington Club',
#                     'The Powell',
#                     'The Bottle Shop',
#                     "Domino's Pizza",
#                     'Par Cha Roen Thai Supermarket',
#                     'Shell Service Station Birchington',
#                     'Premier Stores',
#                     'Happy Nails',
#                     'Birchington Village Bakery',
#                     'Royal Dragon',
#                     "Wendy's Cafe",
#                     'Fishbone Grill',
#                     'All Saints Church Hall',
#                     'Birchington Fast Foods',
#                     'Pixie’s Birchington Ltd',
#                     'Co-op',
#                     'Springfield House',
#                     'Jay Express',
#                     'Birchington United Services Club',
#                     "Mandy's Deli",
#                     "Monty's",
#                     "Zara's",
#                     'Harbour Bakery & Driftwood Cafe',
#                     'The Cabin',
#                     'Highfield',
#                     'BVCA',
#                     'Golden Bridge',
#                     'Seaview Hotel',
#                     "Sainsbury's",
#                     'Blend Coffee Lounge',
#                     'Tandoori Nite',
#                     'The Wheel Alehouse',
#                     "BBL's",
#                     'R C Wale & Son',
#                     'The Co-operative',
#                     'Turkvaz',
#                     'Minnis Bay Fish & Chips',
#                     'The Parlour',
#                     'Christies',
#                     'Spencer House Nursing Home',
#                     'Birchington on Sea Bowls Club',
#                     'Beach House',
#                     'Grenham Bay Court',
#                     'Edgecliff Boutique B & B',
#                     'Twentieth Century B&B',
#                     "Joe's",
#                     'Best One',
#                     'The Bouncing Bomb Cafe',
#                     'Feelgoodmotherhood',
#                     'The Bay Fish Bar',
#                     'The Windshack',
#                     'Crown Inn',
#                     'The Waves Bar,Cafe, B & B Hotel  2',
#                     'Minnis Bay Sailing Club',
#                     'The Minnis Bar & Restaurant',
#                     'The Bay - VCT bikes',
#                     'Sun Inn',
#                     'St Nicholas At Wade C Of E Primary School',
#                     'Post Office',
#                     'Blackboard Schooling Support']}
# {'_id': 'Greenwich',
#  'count': 882,
#  'establishments': ['Black Boy Public House',
#                     'Bexley Foodbank',
#                     'The Pemberdeen Laser Cosmetic Clinic Ltd',
#                     'ISS Facility Services',
#                     'Assessment & Treatment Unit',
#                     'Cygnet Bostall House',
#                     'Breadline Catering Ltd',
#                     'Crafty Wizard',
#                     'Yasaka Sushi',
#                     'Alderwood Primary School',
#                     'NEW ELTHAM GRILL',
#                     'New Eltham Social Club',
#                     'Premier',
#                     'Eltham Green School Nursery Ltd',
#                     'The Bubble & Sausage',
#                     "Gill's eells",
#                     'CH&Co Group Ltd',
#                     'ISHA SPICE',
#                     'Ruchita Tandoori',
#                     'Lai Loi Street',
#                     'Pope Street Bar & Kitchen Limited',
#                     'Montbelle Primary School',
#                     'The Alpha Club',
#                     'Avery Hill Youth Hub',
#                     'Monkey Puzzle Eltham',
#                     'Village Nursery',
#                     '3rd Royal Eltham Scouts',
#                     'Churros Libre',
#                     'The Dome Eatery',
#                     'Student Union Village Shop',
#                     'Premium Off Licence',
#                     "Elsie's Pie N Mash",
#                     'Codfellas',
#                     'Dominos Pizza',
#                     'New Eltham Library Coffee Shop',
#                     'Abbey Wood Caravan and Motorhome Club',
#                     'Co-op Food',
#                     'Crafty Wizards Ltd',
#                     'CAFTAO',
#                     'Farmhouse Public House',
#                     'The Beehive',
#                     'Sunrise Takeaway',
# ...
#                     'Beam Guest House',
#                     'Brooklyn House',
#                     'Travelodge',
#                     'Toby Carvery',
#                     'Beeches Guest House',
#                     'Papa John',
#                     "Domino's Pizza",
#                     'Home Acre',
#                     'Jamrocks Caribbean Cuisine',
#                     'The Terrace',
#                     'Princes Theatre (Essex Hall)',
#                     'Sweets R Us',
#                     'Robbie Rascals Party Centre',
#                     'Mermaids Burger Bar',
#                     'Fairview',
#                     'Essex Fresh Start Independent School',
#                     'Regent House',
#                     'Haven Lodge',
#                     'Adelaide Guest House',
#                     'Sweet Street',
#                     'Playpalz Party and Softplay Centre Ltd',
#                     "Jenny's House",
#                     'Andos',
#                     'Creative Chefs',
#                     'CSC Ltd',
#                     'Body and Soul Food',
#                     'Aldersgate Welcome Inn',
#                     'Golden Plaice',
#                     'St Marks Care Home',
#                     'T Ann Cakes',
#                     'Bluebird Tearoom',
#                     'Aldi Stores Ltd',
#                     'Koekoek Restaurants Ltd',
#                     'Century Cinema',
#                     'Kingston House',
#                     'Mondial',
#                     'Costa',
#                     'Iceland',
#                     'Spring Lodge',
#                     'The Cavendish',
#                     'Bargain Hunters',
#                     'Hearty Pies',
#                     'Asda',
#                     "Big E's Diner",
#                     'TALCO INTERNATIONAL FOODS ( Tandoori Express)',
#                     'The Kaz Bar',
#                     '2 Hearts Catering',
#                     'Halfway House',
#                     'Nineteenth Catering at Clacton Golf Club',
#                     "Sai's Kitchen",
#                     'East of England Co-op',
#                     'Pizza Hut',
#                     'Eat One 8 One',
#                     'Clacton Conservative Club',
#                     "Amy's",
#                     'Londis',
#                     'Traditional Home Meals',
#                     'Burrsville Infant Academy',
#                     'Alton Park Junior School',
#                     'Queens Arms',
#                     'Comrades Sports and Social Club',
#                     'Seconds Out Gym Sandwich Bar',
#                     'Birch Hall Adventures',
#                     'Magdalen Close Hostel',
#                     'Clacton Ice Cream (2015) Ltd',
#                     'London Road Garage (Esso)',
#                     "Reg's",
#                     'Totally Scrumptious Cake Company',
#                     'St Marks & Hall',
#                     'Oakwood Infant School',
#                     'Subway',
#                     'Costa',
#                     'Home Bargains',
#                     'Booker Cash and Carry',
#                     'Just Spuds',
#                     'Asterbourne Chinese Takeaway',
#                     'The Chippy',
#                     'Stores',
#                     'Sun Yau',
#                     'CTC Freshway',
#                     'Almond Art',
#                     'Amazing Activities Limited',
#                     'Chestnut Grove Kindergarten',
#                     'East of England Co-op',
#                     "Gary's Fish and Chips",
#                     'Kiln Barn Stores',
#                     'Lidl',
#                     'Cafe On The Green',
#                     'United Services Club',
#                     'Childrens Respite Care Ltd',
#                     'Achieving Aspiration',
#                     'Fry Inn',
#                     'McColls',
#                     'Alexandra House',
#                     'J & J Wilson',
#                     'Family Shopper',
#                     'The Good Life',
#                     'Deli 141',
#                     "King's Arms",
#                     'Dovercourt House Care Home',
#                     'Tesco',
#                     'Reynolds Newsagents',
#                     'The Waterfront',
#                     'Peking Chinese Restaurant',
#                     'Tasty Takeaway',
#                     'KFC (Brook Retail Park)',
#                     'Tesco Bakery Counter',
#                     'Elior UK',
#                     'Tesco Deli Counter',
#                     'RB Stores',
#                     'Pieseas Chippy',
#                     'Iceland',
#                     'USA Fried Chicken',
#                     'Cabin Bakery',
#                     'Roberts Cafe \\& Bar Restaurant',
#                     'The Cats Whiskers',
#                     'LOCO Cafe \\& Pizzeria',
#                     'Treo Bar Café',
#                     'Old Bank Studios',
#                     'Shakers Bar',
#                     "Terry's Fresh Fish",
#                     "Peri's Mini Mart",
#                     "Jenny's Resource Ltd",
#                     'Langley House Harwich Ltd',
#                     'Cann Hall  Primary School',
#                     "St Joseph's Catholic Primary School",
#                     'New Bell Inn',
#                     'Inclusion Ventures',
#                     'Jaywick Community Resource Centre',
#                     'Tower Hotel',
#                     'Rainbow Cafe / Takeaway',
#                     'Pauls Mobile Restaurant',
#                     'Samuel Pepys Wine Bar',
#                     'Globe',
#                     'Thai Up at The Quay',
#                     'RNLI Sales Ltd',
#                     'Cafe On The Pier & Pier Seafoods',
#                     'Baked By The Sea',
#                     'Reedlands Farm',
#                     'St Clares Primary School',
#                     'ASDA',
#                     'Sir Martin Frobisher Academy',
#                     'ISS Facility Services Education',
#                     'Mr Cadburys',
#                     'Ravens Academy',
#                     'Harwich Sports Hall',
#                     'Lime Court Care Centre',
#                     'One Stop',
#                     'Nisa Local',
#                     'Don Thomson House',
#                     'Cottage Walk - Achieve Together',
#                     'Bockings Elm Post Office',
#                     'Brace Of Pistols',
#                     'Harwich School The Lighthouse Canteen',
#                     'Vines Service Station',
#                     'Woodrows Nursery',
#                     'The Wick Lodge Bar and Resturant',
#                     'Brain Injury Rehabilitation Trust',
#                     'Fryatt Hospital',
#                     'Rosebank Park',
#                     'Blue Garden Cafe',
#                     'Little Clacton Village Hall',
#                     'Sailor Boy Freehouse',
#                     'Sailor Boy Cafe',
#                     'East of England Co-op Foodstore',
#                     'Upper Dovercourt Post Office',
#                     'Sailor Boy Fish \\& Chip Shop',
#                     'All Saints School',
#                     'Edwards of Harwich',
#                     'Health & Happiness',
#                     'Dovercourt Grill',
#                     'Tipmalee',
#                     'Lifehouse',
#                     'Engaines Primary School',
#                     'Spring Meadow School House Nursery',
#                     'Morrisons Daily',
#                     'McDonalds',
#                     'Costa Coffee',
#                     'Morrisons',
#                     'The Mayflower Brewers Fayre',
#                     "Domino's Pizza",
#                     "Nemo's Sea Food",
#                     'Little Paddocks',
#                     'Slush Rush',
#                     'Caribbean Slush Hut',
#                     'Take Away Express',
#                     'Holiday Inn Diner',
#                     'Tudor Bar',
#                     'The Village Inn',
#                     'Dollys Pantry',
#                     'Tollgate Post Office',
#                     'NMK Newsagents',
#                     'Fry Fish and Grill',
#                     'Oakley Pharmacy',
#                     'Tendring Technology College',
#                     'The Fryatt Hotel \\& Bar',
#                     'One Stop',
#                     'Skippers',
#                     'Rolph Primary School',
#                     'Oakwood Plough Corner',
#                     'Simply Chocolate Fountains',
#                     'Vijil Catering',
#                     'Tamarind',
#                     'Ye Olde Cherry Tree',
#                     'Tesco',
#                     'Cloverwood General Store',
#                     'Quayside Cafe (Churchill Catering Ltd)',
#                     'Rose And Crown',
#                     'Two Village CofE (VC) Primary School',
#                     'Smoked Out BBQ',
#                     'Watershed Studios',
#                     'Priory Group',
#                     'The Village Chippy',
#                     'St Osyth Chuch of England Primary School',
#                     'Lime Trees',
#                     'White Hart',
#                     'Dukes Tea Room and Bistro',
#                     'St Osyth Butchers',
#                     'TLC Care Homes',
#                     'Creams \\& Coffee (Formley Eco Ice Creams)',
#                     'Cotchel Mobile Event Trailer',
#                     'St Osyth Preschool',
#                     'Brooke-lynne Farm Shop',
#                     "East Coast Pizza's Ltd",
#                     'White Heather Care',
#                     'Floral Days Cafe',
#                     'The Shy Pig',
#                     'Brokhowse',
#                     'TLC Care Homes',
#                     'Foresters Tavern',
#                     'Willow Park Resource Centre',
#                     'St Andrews Primary School',
#                     'Homestead Cabin Cafe',
#                     'Weeley Post Office',
#                     'Five Stacks Residential Home',
#                     'Gaunts Bakery',
#                     'Black Boy',
#                     'Stour Valley Organic Produce',
#                     'Grove Farm',
#                     'McDonalds',
#                     'MFG Weeley Service Station',
#                     'Tudor Restaurant',
#                     'Ford Barns',
#                     'The Fusilier',
#                     'Oaks',
#                     'Brewstar Coffee',
#                     'Wix Village Hall',
#                     'Waggon',
#                     'Orchards Holiday Village',
#                     'Burger King',
#                     'Show Bar and Papa Johns',
#                     'Bowling Green',
#                     'Rays Burgers',
#                     'The Rosebud',
#                     'Wix and Wrabness Primary School',
#                     'Wix and Wrabness Pre School',
#                     'Coach House Coffee Shop',
#                     'UCSC Ltd (University Community Sailing Club)',
#                     "BB's",
#                     'The Ferryboat Inn',
#                     'Ferry Boat Inn',
#                     'T\\&Cake',
#                     'The Cottage',
#                     'Raj Spice',
#                     "BWYC 'The Old Sail Loft'",
#                     'Fresh Cafe',
#                     'Bumbles Greengrocers',
#                     'Royal British Legion',
#                     'Brightlingsea Sailing Club',
#                     'S W Services',
#                     'Tesco',
#                     'Brightlingsea Play Centre',
#                     'Co-op Daily',
#                     'The Kings Head',
#                     'Brightlingsea Bowls Club',
#                     'Brightlingsea Infant School',
#                     'Brightlingsea Junior School',
#                     'Brightlingsea Community Centre Coffee Morning',
#                     'Tesco',
#                     'The Plough Inn',
#                     'China Palace',
#                     'Brightlingsea Community  Association',
#                     "Bateman's Tower Café",
#                     'Cafe Lido',
#                     'Great Bentley Primary School',
#                     'D Spence Family Butchers Ltd',
#                     "Big Al's Shack",
#                     'Restaurant 43',
#                     'Great Bentley Methodist Church & Hall',
#                     'Four Winds',
#                     'The Cherry Tree',
#                     'Oaklands',
#                     'Graham Watkins',
#                     'Corner Service Station',
#                     'Shell Corner',
#                     'Croft',
#                     'Cake - Quest',
#                     'Oaktree Manor',
#                     'Duck & Pheasant / Coot \\& Moorhen',
#                     'Fiveways Petrol Station',
#                     "Mac's Gourmet Hot Dogs",
#                     'East of England Co-op',
#                     'Ladybirds Pre-School',
#                     'Stuart Hazell (Ice Cream Mobile)',
#                     'Stuart Hazell (Burger Van)',
#                     'Stronvar',
#                     'Bamburgh House Ltd',
#                     'Futures',
#                     'Danshell Adult Healthcare',
#                     'Quenby Residential Home',
#                     'Black Jacket Events Ltd',
#                     'The Roscoe Cakery',
#                     "Sorano's Ltd",
#                     'Mouse House Bakes',
#                     'The Village Maid',
#                     'Bricklayers Arms',
#                     'Strangers Home',
#                     'The Old Ram and Hoggett Tearoom',
#                     'Bradfield News Limited',
#                     'Rostrum Cafe',
#                     'Baxter Storey - Penguin Random House',
#                     'Meadowcroft',
#                     'Alresford Family Support',
#                     'Larchcroft Trading Co Ltd',
#                     'The Court House',
#                     'Spar',
#                     'Solo Cheese Ltd',
#                     'Tara Traders',
#                     'Alresford Fish Bar',
#                     'Sizzlers',
#                     'Pointer Inn',
#                     'True Celebrations',
#                     'Mistley Norman Primary School',
#                     'Butterflys',
#                     'Elm House',
#                     "Becky's Butchers",
#                     'Heidi (TheStation Wagon)',
#                     'The Shed Cafe',
#                     "St George's C of E School",
#                     'Sunnymead Kitchen',
#                     'Beth George',
#                     'Swiss Farm Limited',
#                     'Mitchell Farm Shop',
#                     'Seven Rivers Cheshire Home',
#                     'Mistley Manor Care Home',
#                     'The Crown',
#                     'Tesco',
#                     'Select Catering',
#                     'Dragon House',
#                     'Market Field School',
#                     'Cafe Rio',
#                     'Hobsons Deli \\& Cafe',
#                     'Chilvers Fish Shop',
#                     'Stour Fruiterers',
#                     'Skinners Arms',
#                     'Elm Cottage',
#                     'Simply Thai',
#                     'Manningtree Grill and Pizza',
#                     'Sibbons Plant Hire',
#                     'East of England Co-op',
#                     'Ragmarsh Farm Burger Bar',
#                     'Highfields Primary School',
#                     'Busy Bees Kindergarten',
#                     'Honeycroft Post Office',
#                     'Stour View Stores',
#                     'Manningtree High School',
#                     'Lawford C of E Primary School',
#                     'Crumb & Brew',
#                     'Elmstead Primary School',
#                     'The Cupcake Oven',
#                     'Cake My Day',
#                     'Lawford Football Club',
#                     'The Hunger Cure',
#                     'Riverford Organic',
#                     'Craft Nurseries Coffee Shop',
#                     'Christines',
#                     'Elm Park Brain Injury Services',
#                     "St Mary's Primary School",
#                     'Orchard Barns Kindergarten',
#                     'The Bungalow',
#                     'Crown Inn',
#                     'Jubilee Cafe',
#                     'KFC Ardleigh',
#                     'KFC Ardleigh']}

# %%
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {
        "_id": "$LocalAuthorityName",  
        "count": {"$sum": 1}, }},
    {"$sort": {"count": -1}}  
]

# Execute the aggregation pipeline
results = establishments.aggregate(pipeline)

# Convert the result to a list and then to a Pandas DataFrame
result_list = list(results)
df = pd.DataFrame(result_list)

# Display the number of rows in the DataFrame
print(f"Number of rows: {len(df)}")

# Display the first 10 rows of the DataFrame
df.head(5)
# Out:
# Number of rows: 55
#          _id  count
# 0     Thanet   1130
# 1  Greenwich    882
# 2  Maidstone    713
# 3     Newham    711
# 4      Swale    686
